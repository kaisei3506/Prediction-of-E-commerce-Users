# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisei3506/Prediction-of-E-commerce-Users/blob/main/lgbm_xgb_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import holidays

# %%
train = pd.read_csv('/content/drive/MyDrive/Kaggle/Prediction_of_E-commerce_Users/train_df.csv')
test = pd.read_csv('/content/drive/MyDrive/Kaggle/Prediction_of_E-commerce_Users/test_df.csv')

# %%
train['datetime'] = pd.to_datetime(train['datetime'])
test['datetime'] = pd.to_datetime(test['datetime'])
train = train.set_index('datetime')
test = test.set_index('datetime')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23376 entries, 2022-01-01 00:00:00 to 2024-08-31 23:00:00
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   e_users      23376 non-null  int64
#  1   promotion_1  23376 non-null  float64
#  2   promotion_2  23376 non-null  float64
#  3   promotion_3  23376 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 913.1 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2928 entries, 2024-09-01 00:00:00 to 2024-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   promotion_1  2928 non-null   float64
#  1   promotion_2  2928 non-null   float64
#  2   promotion_3  2928 non-null   float64
# dtypes: float64(3)
# memory usage: 91.5 KB

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['e_users'])
plt.grid()
plt.show()

# %%
'''
# STL分解
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(train['e_users'], model='additive', period=24*7)
fig, ax = plt.subplots(4, 1, figsize=(12, 10))
decomposition.trend.plot(ax=ax[0])
ax[0].set_title('Trend')
decomposition.seasonal.plot(ax=ax[1])
ax[1].set_title('Seasonal')
decomposition.resid.plot(ax=ax[2])
ax[2].set_title('Residual')
decomposition.observed.plot(ax=ax[3])
ax[3].set_title('Observed')
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# STL分解\nfrom statsmodels.tsa.seasonal import seasonal_decompose\n\ndecomposition = seasonal_decompose(train['e_users'], model='additive', period=24*7)\nfig, ax = plt.subplots(4, 1, figsize=(12, 10))\ndecomposition.trend.plot(ax=ax[0])\nax[0].set_title('Trend')\ndecomposition.seasonal.plot(ax=ax[1])\nax[1].set_title('Seasonal')\ndecomposition.resid.plot(ax=ax[2])\nax[2].set_title('Residual')\ndecomposition.observed.plot(ax=ax[3])\nax[3].set_title('Observed')\nplt.tight_layout()\nplt.show()\n"

# %%
# 自己相関と偏自己相関
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(train['e_users'], ax=ax[0], lags=24*7)
plot_pacf(train['e_users'], ax=ax[1], lags=24*7)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_values = acf(train['e_users'], nlags=100)
best_lag = (acf_values > 0.2).argmax()  # 相関が 0.2 を下回る最小のラグ
print(f"推奨ラグ: {best_lag}")
# Out:
# 推奨ラグ: 0

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['e_users'])
plt.xlim(pd.to_datetime('2022-03-01'), pd.to_datetime('2022-05-01'))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['e_users'])
plt.xlim(pd.to_datetime('2023-03-01'), pd.to_datetime('2023-05-01'))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['e_users'])
plt.xlim(pd.to_datetime('2024-03-01'), pd.to_datetime('2024-04-01'))
plt.grid()
plt.show()

# %% [markdown]
# 1年くらいの周期あり？

# %%
df = pd.concat([train, test])
df
# Out:
#                      e_users  promotion_1  promotion_2  promotion_3
# datetime
# 2022-01-01 00:00:00  60545.0        11.67        95.28        80.76
# 2022-01-01 01:00:00  57890.0        11.33        93.25        80.81
# 2022-01-01 02:00:00  57021.0        11.01        91.23        80.85
# 2022-01-01 03:00:00  54162.0        10.82        89.40        80.89
# 2022-01-01 04:00:00  51772.0        10.80        88.14        80.94
# ...                      ...          ...          ...          ...
# 2024-12-31 19:00:00      NaN         7.95        91.67        83.91
# 2024-12-31 20:00:00      NaN         7.62        91.82        85.29
# 2024-12-31 21:00:00      NaN         8.58        91.85        86.35
# 2024-12-31 22:00:00      NaN        10.86        91.50        86.43
# 2024-12-31 23:00:00      NaN        13.43        91.15        86.52
#
# [26304 rows x 4 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['promotion_1'], label='Promotion1')
plt.plot(df['promotion_2'], label='Promotion2')
plt.plot(df['promotion_3'], label='Promotion3')
plt.legend()
plt.grid()
plt.show()

# %%
train
# Out:
#                      e_users  promotion_1  promotion_2  promotion_3
# datetime
# 2022-01-01 00:00:00    60545        11.67        95.28        80.76
# 2022-01-01 01:00:00    57890        11.33        93.25        80.81
# 2022-01-01 02:00:00    57021        11.01        91.23        80.85
# 2022-01-01 03:00:00    54162        10.82        89.40        80.89
# 2022-01-01 04:00:00    51772        10.80        88.14        80.94
# ...                      ...          ...          ...          ...
# 2024-08-31 19:00:00    47980        18.52        73.52        66.95
# 2024-08-31 20:00:00    46915        17.53        71.67        71.15
# 2024-08-31 21:00:00    45963        16.67        70.77        74.84
# 2024-08-31 22:00:00    43917        16.03        72.72        77.02
# 2024-08-31 23:00:00    45364        15.56        74.67        79.19
#
# [23376 rows x 4 columns]

# %%
def engineer(df_old: pd.DataFrame, is_lstm: bool = False) -> pd.DataFrame:

  df = df_old.copy()

  df['p2/p1'] = df['promotion_2'] / df['promotion_1']
  df['p3/p1'] = df['promotion_3'] / df['promotion_1']
  df['p3/p2'] = df['promotion_3'] / df['promotion_2']
  df['p1mulp2'] = df['promotion_1'] * df['promotion_2']
  df['p3mulp1'] = df['promotion_1'] * df['promotion_3']
  df['p2mulp3'] = df['promotion_2'] * df['promotion_3']

  if is_lstm==False:

    for i in range(24):
      df[f'p1_shift{i+1}h'] = df['promotion_1'].shift(i+1)
      df[f'p2_shift{i+1}h'] = df['promotion_2'].shift(i+1)
      df[f'p3_shift{i+1}h'] = df['promotion_3'].shift(i+1)
      df[f'p3mulp1_shift{i+1}h'] = df['p3mulp1'].shift(i+1)

    for i in range(7):
      df[f'p1_shift{i+1}d'] = df['promotion_1'].shift(24*(i+1))
      df[f'p2_shift{i+1}d'] = df['promotion_2'].shift(24*(i+1))
      df[f'p3_shift{i+1}d'] = df['promotion_3'].shift(24*(i+1))
      df[f'p3mulp1_shift{i+1}d'] = df['p3mulp1'].shift(24*(i+1))

    for i in range(4):
      df[f'p1_shift{i+1}w'] = df['promotion_1'].shift(24*7*(i+1))
      df[f'p2_shift{i+1}w'] = df['promotion_2'].shift(24*7*(i+1))
      df[f'p3_shift{i+1}w'] = df['promotion_3'].shift(24*7*(i+1))
      df[f'p3mulp1_shift{i+1}w'] = df['p3mulp1'].shift(24*7*(i+1))


  df['sin_dayofyear'] = np.sin(2 * np.pi * df.index.dayofyear / 366)
  df['cos_dayofyear'] = np.cos(2 * np.pi * df.index.dayofyear / 366)
  df['sin_dayofmonth'] = np.sin(2 * np.pi * df.index.day / 31)
  df['cos_dayofmonth'] = np.cos(2 * np.pi * df.index.day / 31)
  df['sin_dayofweek'] = np.sin(2 * np.pi * df.index.dayofweek / 7)
  df['cos_dayofweek'] = np.cos(2 * np.pi * df.index.dayofweek / 7)
  df['sin_hour'] = np.sin(2 * np.pi * df.index.hour / 24)
  df['cos_hour'] = np.cos(2 * np.pi * df.index.hour / 24)

  #df['march_april'] = df.index.month.isin([3, 4]).astype(int)

  jp_holidays = holidays.Japan()
  #df['is_jp_holiday'] = df.index.to_series().apply(lambda x: x in jp_holidays).astype(int)

  usa_holidays = holidays.US()
  df['is_usa_holiday'] = df.index.to_series().apply(lambda x: x in usa_holidays).astype(int)

  eu_holidays = holidays.EuropeanCentralBank()
  df['is_eu_holiday'] = df.index.to_series().apply(lambda x: x in eu_holidays).astype(int)

  china_holidays = holidays.China()
  df['is_china_holiday'] = df.index.to_series().apply(lambda x: x in china_holidays).astype(int)

  india_holidays = holidays.India()
  df['is_india_holiday'] = df.index.to_series().apply(lambda x: x in india_holidays).astype(int)

  df['log_e_users'] = np.log(df['e_users'])
  df = df.drop('e_users', axis=1)

  # log_e_users以外のカラムの欠損値を削除
  temp = df.dropna(subset=df.columns.drop('log_e_users'))
  df = temp.copy()


  return df

# %%
engineered_df = engineer(df)
engineered_df
# Out:
#                      promotion_1  promotion_2  promotion_3      p2/p1  \
# datetime
# 2022-01-29 00:00:00        10.28        95.49        88.68   9.288911
# 2022-01-29 01:00:00        10.23        95.53        88.53   9.338221
# 2022-01-29 02:00:00        10.27        95.57        88.38   9.305745
# 2022-01-29 03:00:00        10.24        95.54        88.27   9.330078
# 2022-01-29 04:00:00        10.07        95.32        88.28   9.465740
# ...                          ...          ...          ...        ...
# 2024-12-31 19:00:00         7.95        91.67        83.91  11.530818
# 2024-12-31 20:00:00         7.62        91.82        85.29  12.049869
# 2024-12-31 21:00:00         8.58        91.85        86.35  10.705128
# 2024-12-31 22:00:00        10.86        91.50        86.43   8.425414
# 2024-12-31 23:00:00        13.43        91.15        86.52   6.787044
#
#                          p3/p1     p3/p2    p1mulp2    p3mulp1    p2mulp3  \
# datetime
# 2022-01-29 00:00:00   8.626459  0.928684   981.6372   911.6304  8468.0532
# 2022-01-29 01:00:00   8.653959  0.926725   977.2719   905.6619  8457.2709
# 2022-01-29 02:00:00   8.605648  0.924767   981.5039   907.6626  8446.4766
# 2022-01-29 03:00:00   8.620117  0.923906   978.3296   903.8848  8433.3158
# 2022-01-29 04:00:00   8.766634  0.926144   959.8724   888.9796  8414.8496
# ...                        ...       ...        ...        ...        ...
# 2024-12-31 19:00:00  10.554717  0.915349   728.7765   667.0845  7692.0297
# 2024-12-31 20:00:00  11.192913  0.928883   699.6684   649.9098  7831.3278
# 2024-12-31 21:00:00  10.064103  0.940120   788.0730   740.8830  7931.2475
# 2024-12-31 22:00:00   7.958564  0.944590   993.6900   938.6298  7908.3450
# 2024-12-31 23:00:00   6.442293  0.949205  1224.1445  1161.9636  7886.2980
#
#                      p1_shift1h  ...  cos_dayofmonth  sin_dayofweek  \
# datetime                         ...
# 2022-01-29 00:00:00       10.57  ...        0.918958      -0.974928
# 2022-01-29 01:00:00       10.28  ...        0.918958      -0.974928
# 2022-01-29 02:00:00       10.23  ...        0.918958      -0.974928
# 2022-01-29 03:00:00       10.27  ...        0.918958      -0.974928
# 2022-01-29 04:00:00       10.24  ...        0.918958      -0.974928
# ...                         ...  ...             ...            ...
# 2024-12-31 19:00:00        8.89  ...        1.000000       0.781831
# 2024-12-31 20:00:00        7.95  ...        1.000000       0.781831
# 2024-12-31 21:00:00        7.62  ...        1.000000       0.781831
# 2024-12-31 22:00:00        8.58  ...        1.000000       0.781831
# 2024-12-31 23:00:00       10.86  ...        1.000000       0.781831
#
#                      cos_dayofweek  sin_hour  cos_hour  is_usa_holiday  \
# datetime
# 2022-01-29 00:00:00      -0.222521  0.000000  1.000000               0
# 2022-01-29 01:00:00      -0.222521  0.258819  0.965926               0
# 2022-01-29 02:00:00      -0.222521  0.500000  0.866025               0
# 2022-01-29 03:00:00      -0.222521  0.707107  0.707107               0
# 2022-01-29 04:00:00      -0.222521  0.866025  0.500000               0
# ...                            ...       ...       ...             ...
# 2024-12-31 19:00:00       0.623490 -0.965926  0.258819               0
# 2024-12-31 20:00:00       0.623490 -0.866025  0.500000               0
# 2024-12-31 21:00:00       0.623490 -0.707107  0.707107               0
# 2024-12-31 22:00:00       0.623490 -0.500000  0.866025               0
# 2024-12-31 23:00:00       0.623490 -0.258819  0.965926               0
#
#                      is_eu_holiday  is_china_holiday  is_india_holiday  \
# datetime
# 2022-01-29 00:00:00              0                 0                 0
# 2022-01-29 01:00:00              0                 0                 0
# 2022-01-29 02:00:00              0                 0                 0
# 2022-01-29 03:00:00              0                 0                 0
# 2022-01-29 04:00:00              0                 0                 0
# ...                            ...               ...               ...
# 2024-12-31 19:00:00              0                 0                 0
# 2024-12-31 20:00:00              0                 0                 0
# 2024-12-31 21:00:00              0                 0                 0
# 2024-12-31 22:00:00              0                 0                 0
# 2024-12-31 23:00:00              0                 0                 0
#
#                      log_e_users
# datetime
# 2022-01-29 00:00:00    11.030606
# 2022-01-29 01:00:00    10.977209
# 2022-01-29 02:00:00    10.960931
# 2022-01-29 03:00:00    10.913924
# 2022-01-29 04:00:00    10.888707
# ...                          ...
# 2024-12-31 19:00:00          NaN
# 2024-12-31 20:00:00          NaN
# 2024-12-31 21:00:00          NaN
# 2024-12-31 22:00:00          NaN
# 2024-12-31 23:00:00          NaN
#
# [25632 rows x 162 columns]

# %%
temp = engineered_df.copy()

train_engineered = temp[:'2023-12-31']
valid_engineered = temp['2024-01-01':'2024-08-31']
test_engineered = temp['2024-09-01':]

engineered_df_time = engineer(df_old=df, is_lstm=True)
train_time = engineered_df_time[:'2023-12-31']
valid_time = engineered_df_time['2024-01-01':'2024-08-31']
test_time = engineered_df_time['2024-09-01':]

train_valid_time = pd.concat([train_time, valid_time])

# %%
# p1mulp3とp2mulp3の関係をlog_e_usersの値に応じて色を変えてプロット
plt.figure(figsize=(12, 6))
scatter = plt.scatter(temp['p3mulp1'], temp['p2mulp3'], c=temp['log_e_users'], cmap='viridis')
plt.colorbar(scatter, label='log_e_users')  # カラーバーを追加
plt.grid()
plt.xlabel('p1mulp3')
plt.ylabel('p2mulp3')
plt.title('Scatter plot of p1mulp3 vs p2mulp3 colored by log_e_users')
plt.show()

# %%
'''
temp_columns = train.columns.drop('log_e_users')

for i in range(len(temp_columns)):
  for j in range(i+1, len(temp_columns)):
    plt.figure(figsize=(12, 6))
    plt.scatter(train[temp_columns[i]], train[temp_columns[j]], c=train['log_e_users'], cmap='viridis')
    plt.colorbar()
    plt.xlabel(temp_columns[i])
    plt.ylabel(temp_columns[j])
    plt.title(f'Scatter plot of {temp_columns[i]} vs {temp_columns[j]} colored by log_e_users')
    plt.show()
'''
# Out:
# "\ntemp_columns = train.columns.drop('log_e_users')\n\nfor i in range(len(temp_columns)):\n  for j in range(i+1, len(temp_columns)):\n    plt.figure(figsize=(12, 6))\n    plt.scatter(train[temp_columns[i]], train[temp_columns[j]], c=train['log_e_users'], cmap='viridis')\n    plt.colorbar()\n    plt.xlabel(temp_columns[i])\n    plt.ylabel(temp_columns[j])\n    plt.title(f'Scatter plot of {temp_columns[i]} vs {temp_columns[j]} colored by log_e_users')\n    plt.show()\n"

# %%
# p1mulp3とe_usersの関係
plt.figure(figsize=(12, 6))
plt.scatter(train_engineered['p3mulp1'], train_engineered['log_e_users'])
plt.grid()
plt.show()

# %%
X_train = train_engineered.drop('log_e_users', axis=1)
y_train = train_engineered['log_e_users']
X_valid = valid_engineered.drop('log_e_users', axis=1)
y_valid = valid_engineered['log_e_users']
X_test = test_engineered.drop('log_e_users', axis=1)

# %%
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler()
X_train_scaled = X_scaler.fit_transform(X_train)
X_valid_scaled = X_scaler.transform(X_valid)
X_test_scaled = X_scaler.transform(X_test)

y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
y_valid_scaled = y_scaler.transform(y_valid.values.reshape(-1, 1))

# %%
X_train_time = train_time.drop('log_e_users', axis=1)
y_train_time = train_time['log_e_users']
X_valid_time = valid_time.drop('log_e_users', axis=1)
y_valid_time = valid_time['log_e_users']
X_test_time = test_time.drop('log_e_users', axis=1)

X_train_valid_time = train_valid_time.drop('log_e_users', axis=1)
y_train_valid_time = train_valid_time['log_e_users']

# %%
from sklearn.preprocessing import StandardScaler

# ラグ特徴量なし、検証あり
X_scaler_time = StandardScaler()
X_train_scaled_time = X_scaler_time.fit_transform(X_train_time)
X_valid_scaled_time = X_scaler_time.transform(X_valid_time)
X_test_scaled_time = X_scaler_time.transform(X_test_time)

y_scaler_time = StandardScaler()
y_train_scaled_time = y_scaler_time.fit_transform(y_train.values.reshape(-1, 1))
y_valid_scaled_time = y_scaler_time.transform(y_valid.values.reshape(-1, 1))

# ラグ特徴量なし、検証なし
X_scaler_train_valid_time = StandardScaler()
X_train_valid_scaled_time = X_scaler_train_valid_time.fit_transform(X_train_valid_time)
X_test_scaled_time_novalid = X_scaler_train_valid_time.transform(X_test_time)

y_scaler_time_novalid = StandardScaler()
y_train_valid_scaled_time = y_scaler_time_novalid.fit_transform(y_train_valid_time.values.reshape(-1, 1))

# %%
'''
from statsmodels.tsa.statespace.sarimax import SARIMAX

y_sarimax = y_train_valid_time
exog = X_train_valid_scaled_time

sarimax_model = SARIMAX(y_sarimax,
                order=(1, 1, 1),        # (p, d, q)
                seasonal_order=(1, 1, 1, 24),  # (P, D, Q, s)
                exog=exog,
                trend='c',
                enforce_stationarity=False,
                enforce_invertibility=False)
result = sarimax_model.fit(maxiter=20, disp=1)
print(result.summary())
'''
# Out:
# "\nfrom statsmodels.tsa.statespace.sarimax import SARIMAX\n\ny_sarimax = y_train_valid_time\nexog = X_train_valid_scaled_time\n\nsarimax_model = SARIMAX(y_sarimax,\n                order=(1, 1, 1),        # (p, d, q)\n                seasonal_order=(1, 1, 1, 24),  # (P, D, Q, s)\n                exog=exog,\n                trend='c',\n                enforce_stationarity=False,\n                enforce_invertibility=False)\nresult = sarimax_model.fit(maxiter=20, disp=1)\nprint(result.summary())\n"

# %%
'''
steps = len(test_time)
sarimax_test_pred = result.forecast(steps=steps, exog=X_test_scaled_time_novalid)

# sarimax_test_predのプロット
plt.figure(figsize=(12, 6))
plt.plot(index=test_time.index, value=sarimax_test_pred, label='SARIMAX Forecast')
plt.legend()
plt.grid()
plt.show()
'''
# Out:
# "\nsteps = len(test_time)\nsarimax_test_pred = result.forecast(steps=steps, exog=X_test_scaled_time_novalid)\n\n# sarimax_test_predのプロット\nplt.figure(figsize=(12, 6))\nplt.plot(index=test_time.index, value=sarimax_test_pred, label='SARIMAX Forecast')\nplt.legend()\nplt.grid()\nplt.show()\n"

# %%
train
# Out:
#                      e_users  promotion_1  promotion_2  promotion_3
# datetime
# 2022-01-01 00:00:00    60545        11.67        95.28        80.76
# 2022-01-01 01:00:00    57890        11.33        93.25        80.81
# 2022-01-01 02:00:00    57021        11.01        91.23        80.85
# 2022-01-01 03:00:00    54162        10.82        89.40        80.89
# 2022-01-01 04:00:00    51772        10.80        88.14        80.94
# ...                      ...          ...          ...          ...
# 2024-08-31 19:00:00    47980        18.52        73.52        66.95
# 2024-08-31 20:00:00    46915        17.53        71.67        71.15
# 2024-08-31 21:00:00    45963        16.67        70.77        74.84
# 2024-08-31 22:00:00    43917        16.03        72.72        77.02
# 2024-08-31 23:00:00    45364        15.56        74.67        79.19
#
# [23376 rows x 4 columns]

# %%
train_engineered
# Out:
#                      promotion_1  promotion_2  promotion_3      p2/p1  \
# datetime
# 2022-01-29 00:00:00        10.28        95.49        88.68   9.288911
# 2022-01-29 01:00:00        10.23        95.53        88.53   9.338221
# 2022-01-29 02:00:00        10.27        95.57        88.38   9.305745
# 2022-01-29 03:00:00        10.24        95.54        88.27   9.330078
# 2022-01-29 04:00:00        10.07        95.32        88.28   9.465740
# ...                          ...          ...          ...        ...
# 2023-12-31 19:00:00         9.63        88.10        84.76   9.148494
# 2023-12-31 20:00:00         9.43        88.25        85.58   9.358431
# 2023-12-31 21:00:00         9.22        88.93        86.42   9.645336
# 2023-12-31 22:00:00         8.90        91.21        87.38  10.248315
# 2023-12-31 23:00:00         8.57        93.49        88.35  10.908985
#
#                          p3/p1     p3/p2   p1mulp2   p3mulp1    p2mulp3  \
# datetime
# 2022-01-29 00:00:00   8.626459  0.928684  981.6372  911.6304  8468.0532
# 2022-01-29 01:00:00   8.653959  0.926725  977.2719  905.6619  8457.2709
# 2022-01-29 02:00:00   8.605648  0.924767  981.5039  907.6626  8446.4766
# 2022-01-29 03:00:00   8.620117  0.923906  978.3296  903.8848  8433.3158
# 2022-01-29 04:00:00   8.766634  0.926144  959.8724  888.9796  8414.8496
# ...                        ...       ...       ...       ...        ...
# 2023-12-31 19:00:00   8.801661  0.962089  848.4030  816.2388  7467.3560
# 2023-12-31 20:00:00   9.075292  0.969745  832.1975  807.0194  7552.4350
# 2023-12-31 21:00:00   9.373102  0.971776  819.9346  796.7924  7685.3306
# 2023-12-31 22:00:00   9.817978  0.958009  811.7690  777.6820  7969.9298
# 2023-12-31 23:00:00  10.309218  0.945021  801.2093  757.1595  8259.8415
#
#                      p1_shift1h  ...  cos_dayofmonth  sin_dayofweek  \
# datetime                         ...
# 2022-01-29 00:00:00       10.57  ...        0.918958      -0.974928
# 2022-01-29 01:00:00       10.28  ...        0.918958      -0.974928
# 2022-01-29 02:00:00       10.23  ...        0.918958      -0.974928
# 2022-01-29 03:00:00       10.27  ...        0.918958      -0.974928
# 2022-01-29 04:00:00       10.24  ...        0.918958      -0.974928
# ...                         ...  ...             ...            ...
# 2023-12-31 19:00:00       10.03  ...        1.000000      -0.781831
# 2023-12-31 20:00:00        9.63  ...        1.000000      -0.781831
# 2023-12-31 21:00:00        9.43  ...        1.000000      -0.781831
# 2023-12-31 22:00:00        9.22  ...        1.000000      -0.781831
# 2023-12-31 23:00:00        8.90  ...        1.000000      -0.781831
#
#                      cos_dayofweek  sin_hour  cos_hour  is_usa_holiday  \
# datetime
# 2022-01-29 00:00:00      -0.222521  0.000000  1.000000               0
# 2022-01-29 01:00:00      -0.222521  0.258819  0.965926               0
# 2022-01-29 02:00:00      -0.222521  0.500000  0.866025               0
# 2022-01-29 03:00:00      -0.222521  0.707107  0.707107               0
# 2022-01-29 04:00:00      -0.222521  0.866025  0.500000               0
# ...                            ...       ...       ...             ...
# 2023-12-31 19:00:00       0.623490 -0.965926  0.258819               0
# 2023-12-31 20:00:00       0.623490 -0.866025  0.500000               0
# 2023-12-31 21:00:00       0.623490 -0.707107  0.707107               0
# 2023-12-31 22:00:00       0.623490 -0.500000  0.866025               0
# 2023-12-31 23:00:00       0.623490 -0.258819  0.965926               0
#
#                      is_eu_holiday  is_china_holiday  is_india_holiday  \
# datetime
# 2022-01-29 00:00:00              0                 0                 0
# 2022-01-29 01:00:00              0                 0                 0
# 2022-01-29 02:00:00              0                 0                 0
# 2022-01-29 03:00:00              0                 0                 0
# 2022-01-29 04:00:00              0                 0                 0
# ...                            ...               ...               ...
# 2023-12-31 19:00:00              0                 0                 0
# 2023-12-31 20:00:00              0                 0                 0
# 2023-12-31 21:00:00              0                 0                 0
# 2023-12-31 22:00:00              0                 0                 0
# 2023-12-31 23:00:00              0                 0                 0
#
#                      log_e_users
# datetime
# 2022-01-29 00:00:00    11.030606
# 2022-01-29 01:00:00    10.977209
# 2022-01-29 02:00:00    10.960931
# 2022-01-29 03:00:00    10.913924
# 2022-01-29 04:00:00    10.888707
# ...                          ...
# 2023-12-31 19:00:00    11.152544
# 2023-12-31 20:00:00    11.108665
# 2023-12-31 21:00:00    11.065872
# 2023-12-31 22:00:00    11.054297
# 2023-12-31 23:00:00    11.106370
#
# [16848 rows x 162 columns]

# %%
from prophet import Prophet
from sklearn.metrics import mean_squared_error

# Initialize Prophet model
prophet_model = Prophet(
    changepoint_prior_scale=0.5,
    yearly_seasonality=True,  # 年単位の季節性は無効化（短期予測では不要）
    weekly_seasonality=True,  # 週単位の季節性を追加
    daily_seasonality=True    # 日単位の季節性を追加
)

# 外生変数（追加回帰変数）をモデルに追加
prophet_model.add_regressor('promotion_1')
prophet_model.add_regressor('promotion_2')
prophet_model.add_regressor('promotion_3')
# 1時間ごとの周期性を追加（24時間周期で変動するものを考慮）
prophet_model.add_seasonality(name='hourly', period=24, fourier_order=8)

prophet_train = pd.DataFrame()
prophet_train['ds'] = train_engineered.index
prophet_train['y'] = train_engineered['log_e_users'].values
prophet_train['promotion_1'] = train_engineered['promotion_1'].values
prophet_train['promotion_2'] = train_engineered['promotion_2'].values
prophet_train['promotion_3'] = train_engineered['promotion_3'].values
prophet_train

# Train the model
prophet_model.fit(prophet_train)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpl_avfk6m/cm0q50kv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpl_avfk6m/z4ht2xnk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93477', 'data', 'file=/tmp/tmpl_avfk6m/cm0q50kv.json', 'init=/tmp/tmpl_avfk6m/z4ht2xnk.json', 'output', 'file=/tmp/tmpl_avfk6m/prophet_modelhi6a4fpn/prophet_model-20250325060135.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:01:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:02:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Generate future dataframe for validation set
future_valid_test = prophet_model.make_future_dataframe(periods=len(pd.concat([valid_engineered, test_engineered])), freq='H')

# 未来のデータに外生変数を追加（予測時にも必要）
# future_valid_test に valid_engineered, test_engineered の temperature をマージ
train_engineered = train_engineered.reset_index().rename(columns={'datetime': 'ds'})
valid_engineered = valid_engineered.reset_index().rename(columns={'datetime': 'ds'})
test_engineered = test_engineered.reset_index().rename(columns={'datetime': 'ds'})

future_valid_test = future_valid_test.merge(
    pd.concat([train_engineered[['ds', 'promotion_1', 'promotion_2', 'promotion_3']], valid_engineered[['ds', 'promotion_1', 'promotion_2', 'promotion_3']], test_engineered[['ds', 'promotion_1', 'promotion_2', 'promotion_3']]]),
    on='ds',
    how='left'
)

train_engineered = train_engineered.rename(columns={'ds': 'datetime'}).set_index('datetime')
valid_engineered = valid_engineered.rename(columns={'ds': 'datetime'}).set_index('datetime')
test_engineered = test_engineered.rename(columns={'ds': 'datetime'}).set_index('datetime')

forecast = prophet_model.predict(future_valid_test)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                        ds       yhat  yhat_lower  yhat_upper
# 25627 2024-12-31 19:00:00  10.908115    3.764104   17.864567
# 25628 2024-12-31 20:00:00  10.900650    3.757491   17.864413
# 25629 2024-12-31 21:00:00  10.866111    3.792029   17.869734
# 25630 2024-12-31 22:00:00  10.820300    3.734958   17.845906
# 25631 2024-12-31 23:00:00  10.777179    3.644027   17.774975

# %%
future_valid_test
# Out:
#                        ds  promotion_1  promotion_2  promotion_3
# 0     2022-01-29 00:00:00        10.28        95.49        88.68
# 1     2022-01-29 01:00:00        10.23        95.53        88.53
# 2     2022-01-29 02:00:00        10.27        95.57        88.38
# 3     2022-01-29 03:00:00        10.24        95.54        88.27
# 4     2022-01-29 04:00:00        10.07        95.32        88.28
# ...                   ...          ...          ...          ...
# 25627 2024-12-31 19:00:00         7.95        91.67        83.91
# 25628 2024-12-31 20:00:00         7.62        91.82        85.29
# 25629 2024-12-31 21:00:00         8.58        91.85        86.35
# 25630 2024-12-31 22:00:00        10.86        91.50        86.43
# 25631 2024-12-31 23:00:00        13.43        91.15        86.52
#
# [25632 rows x 4 columns]

# %%
# valid_engineeredのlog_e_usersとRMSEを計算
print(f'Valid RMSE: {np.sqrt(mean_squared_error(valid_engineered["log_e_users"], forecast["yhat"][-len(valid_engineered):]))}')
# Out:
# Valid RMSE: 0.4966402543276134

# %%
fig1 = prophet_model.plot(forecast)

# %%
fig2 = prophet_model.plot_components(forecast)

# %%
import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error


params = {'objective': 'regression',
          'metric': 'rmse',
          'random_state': 42,
          'n_estimators': 10000,
          'learning_rate': 0.01
          }
lgbm_model = LGBMRegressor(**params)
lgbm_model.fit(X_train, y_train,
               eval_metric='rmse',
               eval_set=[(X_valid, y_valid)],
               callbacks = [lgb.early_stopping(stopping_rounds=50)]
               )
lgbm_train_pred = lgbm_model.predict(X_train)
lgbm_valid_pred = lgbm_model.predict(X_valid)
lgbm_test_pred = lgbm_model.predict(X_test)

print(f'LGBM Train RMSE: {np.sqrt(mean_squared_error(y_train, lgbm_train_pred))}')
print(f'LGBM Valid RMSE: {np.sqrt(mean_squared_error(y_valid, lgbm_valid_pred))}')

plt.figure(figsize=(12, 6))

sns.lineplot(x=X_train.index, y=y_train, label='Train Actual')
sns.lineplot(x=X_valid.index, y=y_valid, label='Valid Actual')
sns.lineplot(x=X_train.index, y=lgbm_train_pred, label='Train Predicted')
sns.lineplot(x=X_valid.index, y=lgbm_valid_pred, label='Valid Predicted')

plt.grid()
plt.legend()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 38605
# [LightGBM] [Info] Number of data points in the train set: 16848, number of used features: 161
# [LightGBM] [Info] Start training from score 10.864685
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1404]	valid_0's rmse: 0.0821995
# LGBM Train RMSE: 0.01479760488860224
# LGBM Valid RMSE: 0.08219948644208495

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error


params = {'metric': 'rmse',
          'random_state': 42,
          'n_estimators': 10000,
          'learning_rate': 0.01}
xgb_model = XGBRegressor(**params, callbacks=[xgb.callback.EarlyStopping(rounds=50)])
xgb_model.fit(X_train, y_train,
              eval_set = [(X_valid, y_valid)]
              )
xgb_train_pred = xgb_model.predict(X_train)
xgb_valid_pred = xgb_model.predict(X_valid)
xgb_test_pred = xgb_model.predict(X_test)

print(f'Train_RMSE: {np.sqrt(mean_squared_error(y_train, xgb_train_pred))}')
print(f'Valid_RMSE: {np.sqrt(mean_squared_error(y_valid, xgb_valid_pred))}')

plt.figure(figsize=(12, 6))

sns.lineplot(x=X_train.index, y=y_train, label='Train Actual')
sns.lineplot(x=X_valid.index, y=y_valid, label='Valid Actual')
sns.lineplot(x=X_train.index, y=xgb_train_pred, label='Train Predicted')
sns.lineplot(x=X_valid.index, y=xgb_valid_pred, label='Valid Predicted')

plt.grid()
plt.legend()
plt.show()
# Out:
# [0]	validation_0-rmse:0.23546
# [1]	validation_0-rmse:0.23376
# [2]	validation_0-rmse:0.23207
# [3]	validation_0-rmse:0.23039
# [4]	validation_0-rmse:0.22873
# [5]	validation_0-rmse:0.22711
# [6]	validation_0-rmse:0.22548
# [7]	validation_0-rmse:0.22388
# [8]	validation_0-rmse:0.22231
# [9]	validation_0-rmse:0.22075
# [10]	validation_0-rmse:0.21921
# [11]	validation_0-rmse:0.21768
# [12]	validation_0-rmse:0.21618
# [13]	validation_0-rmse:0.21470
# [14]	validation_0-rmse:0.21323
# [15]	validation_0-rmse:0.21176
# [16]	validation_0-rmse:0.21033
# [17]	validation_0-rmse:0.20891
# [18]	validation_0-rmse:0.20749
# [19]	validation_0-rmse:0.20609
# [20]	validation_0-rmse:0.20472
# [21]	validation_0-rmse:0.20335
# [22]	validation_0-rmse:0.20201
# [23]	validation_0-rmse:0.20069
# [24]	validation_0-rmse:0.19937
# [25]	validation_0-rmse:0.19807
# [26]	validation_0-rmse:0.19679
# [27]	validation_0-rmse:0.19553
# [28]	validation_0-rmse:0.19428
# [29]	validation_0-rmse:0.19302
# [30]	validation_0-rmse:0.19179
# [31]	validation_0-rmse:0.19057
# [32]	validation_0-rmse:0.18938
# [33]	validation_0-rmse:0.18820
# [34]	validation_0-rmse:0.18704
# [35]	validation_0-rmse:0.18589
# [36]	validation_0-rmse:0.18476
# [37]	validation_0-rmse:0.18362
# [38]	validation_0-rmse:0.18252
# [39]	validation_0-rmse:0.18141
# [40]	validation_0-rmse:0.18032
# [41]	validation_0-rmse:0.17925
# [42]	validation_0-rmse:0.17819
# [43]	validation_0-rmse:0.17713
# [44]	validation_0-rmse:0.17609
# [45]	validation_0-rmse:0.17506
# [46]	validation_0-rmse:0.17404
# [47]	validation_0-rmse:0.17303
# [48]	validation_0-rmse:0.17205
# [49]	validation_0-rmse:0.17106
# [50]	validation_0-rmse:0.17008
# [51]	validation_0-rmse:0.16913
# [52]	validation_0-rmse:0.16817
# [53]	validation_0-rmse:0.16723
# [54]	validation_0-rmse:0.16631
# [55]	validation_0-rmse:0.16539
# [56]	validation_0-rmse:0.16449
# [57]	validation_0-rmse:0.16360
# [58]	validation_0-rmse:0.16271
# [59]	validation_0-rmse:0.16182
# [60]	validation_0-rmse:0.16096
# [61]	validation_0-rmse:0.16012
# [62]	validation_0-rmse:0.15928
# [63]	validation_0-rmse:0.15844
# [64]	validation_0-rmse:0.15760
# [65]	validation_0-rmse:0.15679
# [66]	validation_0-rmse:0.15598
# [67]	validation_0-rmse:0.15519
# [68]	validation_0-rmse:0.15440
# [69]	validation_0-rmse:0.15361
# [70]	validation_0-rmse:0.15279
# [71]	validation_0-rmse:0.15202
# [72]	validation_0-rmse:0.15127
# [73]	validation_0-rmse:0.15053
# [74]	validation_0-rmse:0.14975
# [75]	validation_0-rmse:0.14897
# [76]	validation_0-rmse:0.14826
# [77]	validation_0-rmse:0.14751
# [78]	validation_0-rmse:0.14681
# [79]	validation_0-rmse:0.14607
# [80]	validation_0-rmse:0.14540
# [81]	validation_0-rmse:0.14473
# [82]	validation_0-rmse:0.14402
# [83]	validation_0-rmse:0.14335
# [84]	validation_0-rmse:0.14264
# [85]	validation_0-rmse:0.14202
# [86]	validation_0-rmse:0.14131
# [87]	validation_0-rmse:0.14063
# [88]	validation_0-rmse:0.14000
# [89]	validation_0-rmse:0.13934
# [90]	validation_0-rmse:0.13873
# [91]	validation_0-rmse:0.13808
# [92]	validation_0-rmse:0.13747
# [93]	validation_0-rmse:0.13687
# [94]	validation_0-rmse:0.13629
# [95]	validation_0-rmse:0.13569
# [96]	validation_0-rmse:0.13510
# [97]	validation_0-rmse:0.13450
# [98]	validation_0-rmse:0.13397
# [99]	validation_0-rmse:0.13337
# [100]	validation_0-rmse:0.13280
# [101]	validation_0-rmse:0.13227
# [102]	validation_0-rmse:0.13171
# [103]	validation_0-rmse:0.13119
# [104]	validation_0-rmse:0.13062
# [105]	validation_0-rmse:0.13013
# [106]	validation_0-rmse:0.12961
# [107]	validation_0-rmse:0.12909
# [108]	validation_0-rmse:0.12857
# [109]	validation_0-rmse:0.12810
# [110]	validation_0-rmse:0.12760
# [111]	validation_0-rmse:0.12712
# [112]	validation_0-rmse:0.12661
# [113]	validation_0-rmse:0.12617
# [114]	validation_0-rmse:0.12570
# [115]	validation_0-rmse:0.12523
# [116]	validation_0-rmse:0.12478
# [117]	validation_0-rmse:0.12433
# [118]	validation_0-rmse:0.12389
# [119]	validation_0-rmse:0.12345
# [120]	validation_0-rmse:0.12302
# [121]	validation_0-rmse:0.12260
# [122]	validation_0-rmse:0.12217
# [123]	validation_0-rmse:0.12176
# [124]	validation_0-rmse:0.12135
# [125]	validation_0-rmse:0.12096
# [126]	validation_0-rmse:0.12057
# [127]	validation_0-rmse:0.12017
# [128]	validation_0-rmse:0.11979
# [129]	validation_0-rmse:0.11939
# [130]	validation_0-rmse:0.11899
# [131]	validation_0-rmse:0.11859
# [132]	validation_0-rmse:0.11823
# [133]	validation_0-rmse:0.11785
# [134]	validation_0-rmse:0.11748
# [135]	validation_0-rmse:0.11711
# [136]	validation_0-rmse:0.11676
# [137]	validation_0-rmse:0.11643
# [138]	validation_0-rmse:0.11605
# [139]	validation_0-rmse:0.11571
# [140]	validation_0-rmse:0.11535
# [141]	validation_0-rmse:0.11499
# [142]	validation_0-rmse:0.11469
# [143]	validation_0-rmse:0.11436
# [144]	validation_0-rmse:0.11403
# [145]	validation_0-rmse:0.11370
# [146]	validation_0-rmse:0.11338
# [147]	validation_0-rmse:0.11309
# [148]	validation_0-rmse:0.11277
# [149]	validation_0-rmse:0.11245
# [150]	validation_0-rmse:0.11216
# [151]	validation_0-rmse:0.11187
# [152]	validation_0-rmse:0.11156
# [153]	validation_0-rmse:0.11127
# [154]	validation_0-rmse:0.11096
# [155]	validation_0-rmse:0.11069
# [156]	validation_0-rmse:0.11042
# [157]	validation_0-rmse:0.11013
# [158]	validation_0-rmse:0.10983
# [159]	validation_0-rmse:0.10957
# [160]	validation_0-rmse:0.10929
# [161]	validation_0-rmse:0.10904
# [162]	validation_0-rmse:0.10877
# [163]	validation_0-rmse:0.10850
# [164]	validation_0-rmse:0.10826
# [165]	validation_0-rmse:0.10803
# [166]	validation_0-rmse:0.10779
# [167]	validation_0-rmse:0.10755
# [168]	validation_0-rmse:0.10731
# [169]	validation_0-rmse:0.10708
# [170]	validation_0-rmse:0.10685
# [171]	validation_0-rmse:0.10663
# [172]	validation_0-rmse:0.10640
# [173]	validation_0-rmse:0.10617
# [174]	validation_0-rmse:0.10592
# [175]	validation_0-rmse:0.10571
# [176]	validation_0-rmse:0.10549
# [177]	validation_0-rmse:0.10529
# [178]	validation_0-rmse:0.10508
# [179]	validation_0-rmse:0.10488
# [180]	validation_0-rmse:0.10469
# [181]	validation_0-rmse:0.10448
# [182]	validation_0-rmse:0.10428
# [183]	validation_0-rmse:0.10409
# [184]	validation_0-rmse:0.10389
# [185]	validation_0-rmse:0.10369
# [186]	validation_0-rmse:0.10350
# [187]	validation_0-rmse:0.10330
# [188]	validation_0-rmse:0.10311
# [189]	validation_0-rmse:0.10291
# [190]	validation_0-rmse:0.10273
# [191]	validation_0-rmse:0.10255
# [192]	validation_0-rmse:0.10236
# [193]	validation_0-rmse:0.10217
# [194]	validation_0-rmse:0.10200
# [195]	validation_0-rmse:0.10181
# [196]	validation_0-rmse:0.10162
# [197]	validation_0-rmse:0.10146
# [198]	validation_0-rmse:0.10129
# [199]	validation_0-rmse:0.10113
# [200]	validation_0-rmse:0.10097
# [201]	validation_0-rmse:0.10080
# [202]	validation_0-rmse:0.10064
# [203]	validation_0-rmse:0.10048
# [204]	validation_0-rmse:0.10032
# [205]	validation_0-rmse:0.10017
# [206]	validation_0-rmse:0.10001
# [207]	validation_0-rmse:0.09986
# [208]	validation_0-rmse:0.09973
# [209]	validation_0-rmse:0.09958
# [210]	validation_0-rmse:0.09945
# [211]	validation_0-rmse:0.09929
# [212]	validation_0-rmse:0.09914
# [213]	validation_0-rmse:0.09900
# [214]	validation_0-rmse:0.09886
# [215]	validation_0-rmse:0.09874
# [216]	validation_0-rmse:0.09860
# [217]	validation_0-rmse:0.09845
# [218]	validation_0-rmse:0.09832
# [219]	validation_0-rmse:0.09820
# [220]	validation_0-rmse:0.09807
# [221]	validation_0-rmse:0.09792
# [222]	validation_0-rmse:0.09778
# [223]	validation_0-rmse:0.09765
# [224]	validation_0-rmse:0.09753
# [225]	validation_0-rmse:0.09739
# [226]	validation_0-rmse:0.09725
# [227]	validation_0-rmse:0.09714
# [228]	validation_0-rmse:0.09700
# [229]	validation_0-rmse:0.09688
# [230]	validation_0-rmse:0.09675
# [231]	validation_0-rmse:0.09664
# [232]	validation_0-rmse:0.09651
# [233]	validation_0-rmse:0.09641
# [234]	validation_0-rmse:0.09631
# [235]	validation_0-rmse:0.09617
# [236]	validation_0-rmse:0.09607
# [237]	validation_0-rmse:0.09595
# [238]	validation_0-rmse:0.09585
# [239]	validation_0-rmse:0.09575
# [240]	validation_0-rmse:0.09565
# [241]	validation_0-rmse:0.09556
# [242]	validation_0-rmse:0.09546
# [243]	validation_0-rmse:0.09536
# [244]	validation_0-rmse:0.09526
# [245]	validation_0-rmse:0.09516
# [246]	validation_0-rmse:0.09505
# [247]	validation_0-rmse:0.09497
# [248]	validation_0-rmse:0.09488
# [249]	validation_0-rmse:0.09479
# [250]	validation_0-rmse:0.09470
# [251]	validation_0-rmse:0.09461
# [252]	validation_0-rmse:0.09452
# [253]	validation_0-rmse:0.09443
# [254]	validation_0-rmse:0.09433
# [255]	validation_0-rmse:0.09425
# [256]	validation_0-rmse:0.09416
# [257]	validation_0-rmse:0.09407
# [258]	validation_0-rmse:0.09400
# [259]	validation_0-rmse:0.09391
# [260]	validation_0-rmse:0.09384
# [261]	validation_0-rmse:0.09375
# [262]	validation_0-rmse:0.09367
# [263]	validation_0-rmse:0.09359
# [264]	validation_0-rmse:0.09350
# [265]	validation_0-rmse:0.09342
# [266]	validation_0-rmse:0.09334
# [267]	validation_0-rmse:0.09327
# [268]	validation_0-rmse:0.09319
# [269]	validation_0-rmse:0.09311
# [270]	validation_0-rmse:0.09303
# [271]	validation_0-rmse:0.09297
# [272]	validation_0-rmse:0.09289
# [273]	validation_0-rmse:0.09282
# [274]	validation_0-rmse:0.09274
# [275]	validation_0-rmse:0.09268
# [276]	validation_0-rmse:0.09261
# [277]	validation_0-rmse:0.09254
# [278]	validation_0-rmse:0.09247
# [279]	validation_0-rmse:0.09240
# [280]	validation_0-rmse:0.09233
# [281]	validation_0-rmse:0.09225
# [282]	validation_0-rmse:0.09218
# [283]	validation_0-rmse:0.09212
# [284]	validation_0-rmse:0.09204
# [285]	validation_0-rmse:0.09197
# [286]	validation_0-rmse:0.09192
# [287]	validation_0-rmse:0.09185
# [288]	validation_0-rmse:0.09178
# [289]	validation_0-rmse:0.09170
# [290]	validation_0-rmse:0.09164
# [291]	validation_0-rmse:0.09158
# [292]	validation_0-rmse:0.09152
# [293]	validation_0-rmse:0.09147
# [294]	validation_0-rmse:0.09141
# [295]	validation_0-rmse:0.09134
# [296]	validation_0-rmse:0.09127
# [297]	validation_0-rmse:0.09121
# [298]	validation_0-rmse:0.09115
# [299]	validation_0-rmse:0.09110
# [300]	validation_0-rmse:0.09103
# [301]	validation_0-rmse:0.09096
# [302]	validation_0-rmse:0.09091
# [303]	validation_0-rmse:0.09087
# [304]	validation_0-rmse:0.09081
# [305]	validation_0-rmse:0.09074
# [306]	validation_0-rmse:0.09070
# [307]	validation_0-rmse:0.09064
# [308]	validation_0-rmse:0.09057
# [309]	validation_0-rmse:0.09053
# [310]	validation_0-rmse:0.09047
# [311]	validation_0-rmse:0.09044
# [312]	validation_0-rmse:0.09037
# [313]	validation_0-rmse:0.09034
# [314]	validation_0-rmse:0.09029
# [315]	validation_0-rmse:0.09026
# [316]	validation_0-rmse:0.09021
# [317]	validation_0-rmse:0.09018
# [318]	validation_0-rmse:0.09012
# [319]	validation_0-rmse:0.09007
# [320]	validation_0-rmse:0.09002
# [321]	validation_0-rmse:0.08997
# [322]	validation_0-rmse:0.08992
# [323]	validation_0-rmse:0.08989
# [324]	validation_0-rmse:0.08984
# [325]	validation_0-rmse:0.08980
# [326]	validation_0-rmse:0.08976
# [327]	validation_0-rmse:0.08972
# [328]	validation_0-rmse:0.08967
# [329]	validation_0-rmse:0.08962
# [330]	validation_0-rmse:0.08959
# [331]	validation_0-rmse:0.08954
# [332]	validation_0-rmse:0.08950
# [333]	validation_0-rmse:0.08946
# [334]	validation_0-rmse:0.08942
# [335]	validation_0-rmse:0.08937
# [336]	validation_0-rmse:0.08933
# [337]	validation_0-rmse:0.08929
# [338]	validation_0-rmse:0.08927
# [339]	validation_0-rmse:0.08922
# [340]	validation_0-rmse:0.08919
# [341]	validation_0-rmse:0.08915
# [342]	validation_0-rmse:0.08912
# [343]	validation_0-rmse:0.08908
# [344]	validation_0-rmse:0.08903
# [345]	validation_0-rmse:0.08901
# [346]	validation_0-rmse:0.08896
# [347]	validation_0-rmse:0.08892
# [348]	validation_0-rmse:0.08889
# [349]	validation_0-rmse:0.08886
# [350]	validation_0-rmse:0.08882
# [351]	validation_0-rmse:0.08879
# [352]	validation_0-rmse:0.08876
# [353]	validation_0-rmse:0.08873
# [354]	validation_0-rmse:0.08869
# [355]	validation_0-rmse:0.08866
# [356]	validation_0-rmse:0.08861
# [357]	validation_0-rmse:0.08857
# [358]	validation_0-rmse:0.08854
# [359]	validation_0-rmse:0.08851
# [360]	validation_0-rmse:0.08847
# [361]	validation_0-rmse:0.08844
# [362]	validation_0-rmse:0.08841
# [363]	validation_0-rmse:0.08838
# [364]	validation_0-rmse:0.08834
# [365]	validation_0-rmse:0.08831
# [366]	validation_0-rmse:0.08827
# [367]	validation_0-rmse:0.08824
# [368]	validation_0-rmse:0.08821
# [369]	validation_0-rmse:0.08819
# [370]	validation_0-rmse:0.08814
# [371]	validation_0-rmse:0.08811
# [372]	validation_0-rmse:0.08808
# [373]	validation_0-rmse:0.08805
# [374]	validation_0-rmse:0.08802
# [375]	validation_0-rmse:0.08799
# [376]	validation_0-rmse:0.08797
# [377]	validation_0-rmse:0.08795
# [378]	validation_0-rmse:0.08791
# [379]	validation_0-rmse:0.08789
# [380]	validation_0-rmse:0.08786
# [381]	validation_0-rmse:0.08784
# [382]	validation_0-rmse:0.08782
# [383]	validation_0-rmse:0.08780
# [384]	validation_0-rmse:0.08777
# [385]	validation_0-rmse:0.08775
# [386]	validation_0-rmse:0.08772
# [387]	validation_0-rmse:0.08770
# [388]	validation_0-rmse:0.08768
# [389]	validation_0-rmse:0.08766
# [390]	validation_0-rmse:0.08763
# [391]	validation_0-rmse:0.08762
# [392]	validation_0-rmse:0.08760
# [393]	validation_0-rmse:0.08757
# [394]	validation_0-rmse:0.08754
# [395]	validation_0-rmse:0.08752
# [396]	validation_0-rmse:0.08749
# [397]	validation_0-rmse:0.08747
# [398]	validation_0-rmse:0.08745
# [399]	validation_0-rmse:0.08742
# [400]	validation_0-rmse:0.08740
# [401]	validation_0-rmse:0.08737
# [402]	validation_0-rmse:0.08736
# [403]	validation_0-rmse:0.08732
# [404]	validation_0-rmse:0.08730
# [405]	validation_0-rmse:0.08727
# [406]	validation_0-rmse:0.08724
# [407]	validation_0-rmse:0.08722
# [408]	validation_0-rmse:0.08719
# [409]	validation_0-rmse:0.08717
# [410]	validation_0-rmse:0.08716
# [411]	validation_0-rmse:0.08712
# [412]	validation_0-rmse:0.08710
# [413]	validation_0-rmse:0.08709
# [414]	validation_0-rmse:0.08707
# [415]	validation_0-rmse:0.08705
# [416]	validation_0-rmse:0.08702
# [417]	validation_0-rmse:0.08699
# [418]	validation_0-rmse:0.08697
# [419]	validation_0-rmse:0.08694
# [420]	validation_0-rmse:0.08693
# [421]	validation_0-rmse:0.08690
# [422]	validation_0-rmse:0.08687
# [423]	validation_0-rmse:0.08685
# [424]	validation_0-rmse:0.08682
# [425]	validation_0-rmse:0.08680
# [426]	validation_0-rmse:0.08678
# [427]	validation_0-rmse:0.08676
# [428]	validation_0-rmse:0.08674
# [429]	validation_0-rmse:0.08671
# [430]	validation_0-rmse:0.08670
# [431]	validation_0-rmse:0.08668
# [432]	validation_0-rmse:0.08666
# [433]	validation_0-rmse:0.08662
# [434]	validation_0-rmse:0.08661
# [435]	validation_0-rmse:0.08658
# [436]	validation_0-rmse:0.08656
# [437]	validation_0-rmse:0.08654
# [438]	validation_0-rmse:0.08651
# [439]	validation_0-rmse:0.08649
# [440]	validation_0-rmse:0.08647
# [441]	validation_0-rmse:0.08644
# [442]	validation_0-rmse:0.08642
# [443]	validation_0-rmse:0.08641
# [444]	validation_0-rmse:0.08639
# [445]	validation_0-rmse:0.08636
# [446]	validation_0-rmse:0.08635
# [447]	validation_0-rmse:0.08633
# [448]	validation_0-rmse:0.08631
# [449]	validation_0-rmse:0.08628
# [450]	validation_0-rmse:0.08627
# [451]	validation_0-rmse:0.08625
# [452]	validation_0-rmse:0.08622
# [453]	validation_0-rmse:0.08620
# [454]	validation_0-rmse:0.08618
# [455]	validation_0-rmse:0.08617
# [456]	validation_0-rmse:0.08615
# [457]	validation_0-rmse:0.08612
# [458]	validation_0-rmse:0.08610
# [459]	validation_0-rmse:0.08608
# [460]	validation_0-rmse:0.08606
# [461]	validation_0-rmse:0.08604
# [462]	validation_0-rmse:0.08601
# [463]	validation_0-rmse:0.08599
# [464]	validation_0-rmse:0.08599
# [465]	validation_0-rmse:0.08597
# [466]	validation_0-rmse:0.08596
# [467]	validation_0-rmse:0.08595
# [468]	validation_0-rmse:0.08594
# [469]	validation_0-rmse:0.08591
# [470]	validation_0-rmse:0.08590
# [471]	validation_0-rmse:0.08589
# [472]	validation_0-rmse:0.08589
# [473]	validation_0-rmse:0.08587
# [474]	validation_0-rmse:0.08585
# [475]	validation_0-rmse:0.08584
# [476]	validation_0-rmse:0.08583
# [477]	validation_0-rmse:0.08581
# [478]	validation_0-rmse:0.08581
# [479]	validation_0-rmse:0.08579
# [480]	validation_0-rmse:0.08576
# [481]	validation_0-rmse:0.08574
# [482]	validation_0-rmse:0.08573
# [483]	validation_0-rmse:0.08571
# [484]	validation_0-rmse:0.08570
# [485]	validation_0-rmse:0.08569
# [486]	validation_0-rmse:0.08569
# [487]	validation_0-rmse:0.08567
# [488]	validation_0-rmse:0.08564
# [489]	validation_0-rmse:0.08563
# [490]	validation_0-rmse:0.08561
# [491]	validation_0-rmse:0.08560
# [492]	validation_0-rmse:0.08558
# [493]	validation_0-rmse:0.08557
# [494]	validation_0-rmse:0.08554
# [495]	validation_0-rmse:0.08553
# [496]	validation_0-rmse:0.08552
# [497]	validation_0-rmse:0.08551
# [498]	validation_0-rmse:0.08550
# [499]	validation_0-rmse:0.08549
# [500]	validation_0-rmse:0.08548
# [501]	validation_0-rmse:0.08547
# [502]	validation_0-rmse:0.08545
# [503]	validation_0-rmse:0.08544
# [504]	validation_0-rmse:0.08542
# [505]	validation_0-rmse:0.08541
# [506]	validation_0-rmse:0.08540
# [507]	validation_0-rmse:0.08539
# [508]	validation_0-rmse:0.08538
# [509]	validation_0-rmse:0.08536
# [510]	validation_0-rmse:0.08535
# [511]	validation_0-rmse:0.08534
# [512]	validation_0-rmse:0.08533
# [513]	validation_0-rmse:0.08532
# [514]	validation_0-rmse:0.08530
# [515]	validation_0-rmse:0.08529
# [516]	validation_0-rmse:0.08528
# [517]	validation_0-rmse:0.08528
# [518]	validation_0-rmse:0.08526
# [519]	validation_0-rmse:0.08525
# [520]	validation_0-rmse:0.08525
# [521]	validation_0-rmse:0.08523
# [522]	validation_0-rmse:0.08522
# [523]	validation_0-rmse:0.08520
# [524]	validation_0-rmse:0.08519
# [525]	validation_0-rmse:0.08518
# [526]	validation_0-rmse:0.08517
# [527]	validation_0-rmse:0.08516
# [528]	validation_0-rmse:0.08515
# [529]	validation_0-rmse:0.08514
# [530]	validation_0-rmse:0.08512
# [531]	validation_0-rmse:0.08511
# [532]	validation_0-rmse:0.08509
# [533]	validation_0-rmse:0.08508
# [534]	validation_0-rmse:0.08506
# [535]	validation_0-rmse:0.08505
# [536]	validation_0-rmse:0.08505
# [537]	validation_0-rmse:0.08503
# [538]	validation_0-rmse:0.08502
# [539]	validation_0-rmse:0.08500
# [540]	validation_0-rmse:0.08499
# [541]	validation_0-rmse:0.08497
# [542]	validation_0-rmse:0.08497
# [543]	validation_0-rmse:0.08496
# [544]	validation_0-rmse:0.08495
# [545]	validation_0-rmse:0.08494
# [546]	validation_0-rmse:0.08494
# [547]	validation_0-rmse:0.08493
# [548]	validation_0-rmse:0.08492
# [549]	validation_0-rmse:0.08492
# [550]	validation_0-rmse:0.08491
# [551]	validation_0-rmse:0.08489
# [552]	validation_0-rmse:0.08489
# [553]	validation_0-rmse:0.08488
# [554]	validation_0-rmse:0.08488
# [555]	validation_0-rmse:0.08486
# [556]	validation_0-rmse:0.08485
# [557]	validation_0-rmse:0.08484
# [558]	validation_0-rmse:0.08482
# [559]	validation_0-rmse:0.08482
# [560]	validation_0-rmse:0.08481
# [561]	validation_0-rmse:0.08480
# [562]	validation_0-rmse:0.08479
# [563]	validation_0-rmse:0.08478
# [564]	validation_0-rmse:0.08477
# [565]	validation_0-rmse:0.08477
# [566]	validation_0-rmse:0.08476
# [567]	validation_0-rmse:0.08475
# [568]	validation_0-rmse:0.08474
# [569]	validation_0-rmse:0.08474
# [570]	validation_0-rmse:0.08472
# [571]	validation_0-rmse:0.08472
# [572]	validation_0-rmse:0.08470
# [573]	validation_0-rmse:0.08470
# [574]	validation_0-rmse:0.08468
# [575]	validation_0-rmse:0.08469
# [576]	validation_0-rmse:0.08469
# [577]	validation_0-rmse:0.08467
# [578]	validation_0-rmse:0.08466
# [579]	validation_0-rmse:0.08466
# [580]	validation_0-rmse:0.08465
# [581]	validation_0-rmse:0.08465
# [582]	validation_0-rmse:0.08465
# [583]	validation_0-rmse:0.08464
# [584]	validation_0-rmse:0.08463
# [585]	validation_0-rmse:0.08462
# [586]	validation_0-rmse:0.08461
# [587]	validation_0-rmse:0.08462
# [588]	validation_0-rmse:0.08461
# [589]	validation_0-rmse:0.08460
# [590]	validation_0-rmse:0.08458
# [591]	validation_0-rmse:0.08457
# [592]	validation_0-rmse:0.08458
# [593]	validation_0-rmse:0.08457
# [594]	validation_0-rmse:0.08456
# [595]	validation_0-rmse:0.08456
# [596]	validation_0-rmse:0.08455
# [597]	validation_0-rmse:0.08454
# [598]	validation_0-rmse:0.08454
# [599]	validation_0-rmse:0.08452
# [600]	validation_0-rmse:0.08453
# [601]	validation_0-rmse:0.08452
# [602]	validation_0-rmse:0.08451
# [603]	validation_0-rmse:0.08450
# [604]	validation_0-rmse:0.08449
# [605]	validation_0-rmse:0.08448
# [606]	validation_0-rmse:0.08447
# [607]	validation_0-rmse:0.08446
# [608]	validation_0-rmse:0.08445
# [609]	validation_0-rmse:0.08446
# [610]	validation_0-rmse:0.08445
# [611]	validation_0-rmse:0.08444
# [612]	validation_0-rmse:0.08444
# [613]	validation_0-rmse:0.08443
# [614]	validation_0-rmse:0.08442
# [615]	validation_0-rmse:0.08441
# [616]	validation_0-rmse:0.08440
# [617]	validation_0-rmse:0.08438
# [618]	validation_0-rmse:0.08437
# [619]	validation_0-rmse:0.08436
# [620]	validation_0-rmse:0.08435
# [621]	validation_0-rmse:0.08432
# [622]	validation_0-rmse:0.08432
# [623]	validation_0-rmse:0.08431
# [624]	validation_0-rmse:0.08429
# [625]	validation_0-rmse:0.08426
# [626]	validation_0-rmse:0.08426
# [627]	validation_0-rmse:0.08426
# [628]	validation_0-rmse:0.08426
# [629]	validation_0-rmse:0.08425
# [630]	validation_0-rmse:0.08424
# [631]	validation_0-rmse:0.08424
# [632]	validation_0-rmse:0.08423
# [633]	validation_0-rmse:0.08422
# [634]	validation_0-rmse:0.08421
# [635]	validation_0-rmse:0.08420
# [636]	validation_0-rmse:0.08419
# [637]	validation_0-rmse:0.08419
# [638]	validation_0-rmse:0.08419
# [639]	validation_0-rmse:0.08418
# [640]	validation_0-rmse:0.08418
# [641]	validation_0-rmse:0.08418
# [642]	validation_0-rmse:0.08417
# [643]	validation_0-rmse:0.08416
# [644]	validation_0-rmse:0.08416
# [645]	validation_0-rmse:0.08416
# [646]	validation_0-rmse:0.08415
# [647]	validation_0-rmse:0.08415
# [648]	validation_0-rmse:0.08415
# [649]	validation_0-rmse:0.08414
# [650]	validation_0-rmse:0.08414
# [651]	validation_0-rmse:0.08413
# [652]	validation_0-rmse:0.08413
# [653]	validation_0-rmse:0.08413
# [654]	validation_0-rmse:0.08412
# [655]	validation_0-rmse:0.08411
# [656]	validation_0-rmse:0.08411
# [657]	validation_0-rmse:0.08410
# [658]	validation_0-rmse:0.08409
# [659]	validation_0-rmse:0.08408
# [660]	validation_0-rmse:0.08407
# [661]	validation_0-rmse:0.08406
# [662]	validation_0-rmse:0.08406
# [663]	validation_0-rmse:0.08406
# [664]	validation_0-rmse:0.08406
# [665]	validation_0-rmse:0.08405
# [666]	validation_0-rmse:0.08404
# [667]	validation_0-rmse:0.08403
# [668]	validation_0-rmse:0.08401
# [669]	validation_0-rmse:0.08401
# [670]	validation_0-rmse:0.08401
# [671]	validation_0-rmse:0.08401
# [672]	validation_0-rmse:0.08400
# [673]	validation_0-rmse:0.08399
# [674]	validation_0-rmse:0.08399
# [675]	validation_0-rmse:0.08398
# [676]	validation_0-rmse:0.08398
# [677]	validation_0-rmse:0.08397
# [678]	validation_0-rmse:0.08396
# [679]	validation_0-rmse:0.08395
# [680]	validation_0-rmse:0.08396
# [681]	validation_0-rmse:0.08395
# [682]	validation_0-rmse:0.08395
# [683]	validation_0-rmse:0.08394
# [684]	validation_0-rmse:0.08394
# [685]	validation_0-rmse:0.08393
# [686]	validation_0-rmse:0.08393
# [687]	validation_0-rmse:0.08392
# [688]	validation_0-rmse:0.08392
# [689]	validation_0-rmse:0.08392
# [690]	validation_0-rmse:0.08391
# [691]	validation_0-rmse:0.08391
# [692]	validation_0-rmse:0.08391
# [693]	validation_0-rmse:0.08390
# [694]	validation_0-rmse:0.08390
# [695]	validation_0-rmse:0.08389
# [696]	validation_0-rmse:0.08389
# [697]	validation_0-rmse:0.08388
# [698]	validation_0-rmse:0.08388
# [699]	validation_0-rmse:0.08388
# [700]	validation_0-rmse:0.08388
# [701]	validation_0-rmse:0.08387
# [702]	validation_0-rmse:0.08386
# [703]	validation_0-rmse:0.08386
# [704]	validation_0-rmse:0.08385
# [705]	validation_0-rmse:0.08384
# [706]	validation_0-rmse:0.08384
# [707]	validation_0-rmse:0.08384
# [708]	validation_0-rmse:0.08384
# [709]	validation_0-rmse:0.08383
# [710]	validation_0-rmse:0.08382
# [711]	validation_0-rmse:0.08383
# [712]	validation_0-rmse:0.08382
# [713]	validation_0-rmse:0.08382
# [714]	validation_0-rmse:0.08381
# [715]	validation_0-rmse:0.08380
# [716]	validation_0-rmse:0.08380
# [717]	validation_0-rmse:0.08380
# [718]	validation_0-rmse:0.08380
# [719]	validation_0-rmse:0.08380
# [720]	validation_0-rmse:0.08380
# [721]	validation_0-rmse:0.08380
# [722]	validation_0-rmse:0.08379
# [723]	validation_0-rmse:0.08379
# [724]	validation_0-rmse:0.08379
# [725]	validation_0-rmse:0.08378
# [726]	validation_0-rmse:0.08378
# [727]	validation_0-rmse:0.08378
# [728]	validation_0-rmse:0.08377
# [729]	validation_0-rmse:0.08377
# [730]	validation_0-rmse:0.08376
# [731]	validation_0-rmse:0.08375
# [732]	validation_0-rmse:0.08376
# [733]	validation_0-rmse:0.08375
# [734]	validation_0-rmse:0.08375
# [735]	validation_0-rmse:0.08374
# [736]	validation_0-rmse:0.08374
# [737]	validation_0-rmse:0.08374
# [738]	validation_0-rmse:0.08374
# [739]	validation_0-rmse:0.08374
# [740]	validation_0-rmse:0.08374
# [741]	validation_0-rmse:0.08374
# [742]	validation_0-rmse:0.08374
# [743]	validation_0-rmse:0.08373
# [744]	validation_0-rmse:0.08373
# [745]	validation_0-rmse:0.08373
# [746]	validation_0-rmse:0.08372
# [747]	validation_0-rmse:0.08372
# [748]	validation_0-rmse:0.08371
# [749]	validation_0-rmse:0.08371
# [750]	validation_0-rmse:0.08371
# [751]	validation_0-rmse:0.08370
# [752]	validation_0-rmse:0.08370
# [753]	validation_0-rmse:0.08370
# [754]	validation_0-rmse:0.08369
# [755]	validation_0-rmse:0.08369
# [756]	validation_0-rmse:0.08368
# [757]	validation_0-rmse:0.08368
# [758]	validation_0-rmse:0.08368
# [759]	validation_0-rmse:0.08367
# [760]	validation_0-rmse:0.08367
# [761]	validation_0-rmse:0.08366
# [762]	validation_0-rmse:0.08366
# [763]	validation_0-rmse:0.08366
# [764]	validation_0-rmse:0.08366
# [765]	validation_0-rmse:0.08365
# [766]	validation_0-rmse:0.08365
# [767]	validation_0-rmse:0.08365
# [768]	validation_0-rmse:0.08365
# [769]	validation_0-rmse:0.08364
# [770]	validation_0-rmse:0.08364
# [771]	validation_0-rmse:0.08363
# [772]	validation_0-rmse:0.08363
# [773]	validation_0-rmse:0.08363
# [774]	validation_0-rmse:0.08364
# [775]	validation_0-rmse:0.08364
# [776]	validation_0-rmse:0.08363
# [777]	validation_0-rmse:0.08363
# [778]	validation_0-rmse:0.08363
# [779]	validation_0-rmse:0.08363
# [780]	validation_0-rmse:0.08362
# [781]	validation_0-rmse:0.08363
# [782]	validation_0-rmse:0.08363
# [783]	validation_0-rmse:0.08363
# [784]	validation_0-rmse:0.08363
# [785]	validation_0-rmse:0.08363
# [786]	validation_0-rmse:0.08363
# [787]	validation_0-rmse:0.08362
# [788]	validation_0-rmse:0.08362
# [789]	validation_0-rmse:0.08362
# [790]	validation_0-rmse:0.08362
# [791]	validation_0-rmse:0.08362
# [792]	validation_0-rmse:0.08362
# [793]	validation_0-rmse:0.08362
# [794]	validation_0-rmse:0.08361
# [795]	validation_0-rmse:0.08361
# [796]	validation_0-rmse:0.08361
# [797]	validation_0-rmse:0.08360
# [798]	validation_0-rmse:0.08361
# [799]	validation_0-rmse:0.08361
# [800]	validation_0-rmse:0.08361
# [801]	validation_0-rmse:0.08361
# [802]	validation_0-rmse:0.08360
# [803]	validation_0-rmse:0.08361
# [804]	validation_0-rmse:0.08361
# [805]	validation_0-rmse:0.08361
# [806]	validation_0-rmse:0.08361
# [807]	validation_0-rmse:0.08361
# [808]	validation_0-rmse:0.08361
# [809]	validation_0-rmse:0.08360
# [810]	validation_0-rmse:0.08360
# [811]	validation_0-rmse:0.08361
# [812]	validation_0-rmse:0.08361
# [813]	validation_0-rmse:0.08361
# [814]	validation_0-rmse:0.08361
# [815]	validation_0-rmse:0.08361
# [816]	validation_0-rmse:0.08361
# [817]	validation_0-rmse:0.08361
# [818]	validation_0-rmse:0.08361
# [819]	validation_0-rmse:0.08361
# [820]	validation_0-rmse:0.08361
# [821]	validation_0-rmse:0.08361
# [822]	validation_0-rmse:0.08360
# [823]	validation_0-rmse:0.08360
# [824]	validation_0-rmse:0.08360
# [825]	validation_0-rmse:0.08359
# [826]	validation_0-rmse:0.08359
# [827]	validation_0-rmse:0.08358
# [828]	validation_0-rmse:0.08358
# [829]	validation_0-rmse:0.08358
# [830]	validation_0-rmse:0.08358
# [831]	validation_0-rmse:0.08358
# [832]	validation_0-rmse:0.08358
# [833]	validation_0-rmse:0.08358
# [834]	validation_0-rmse:0.08358
# [835]	validation_0-rmse:0.08358
# [836]	validation_0-rmse:0.08357
# [837]	validation_0-rmse:0.08356
# [838]	validation_0-rmse:0.08357
# [839]	validation_0-rmse:0.08357
# [840]	validation_0-rmse:0.08357
# [841]	validation_0-rmse:0.08357
# [842]	validation_0-rmse:0.08356
# [843]	validation_0-rmse:0.08356
# [844]	validation_0-rmse:0.08356
# [845]	validation_0-rmse:0.08356
# [846]	validation_0-rmse:0.08356
# [847]	validation_0-rmse:0.08355
# [848]	validation_0-rmse:0.08355
# [849]	validation_0-rmse:0.08354
# [850]	validation_0-rmse:0.08354
# [851]	validation_0-rmse:0.08354
# [852]	validation_0-rmse:0.08354
# [853]	validation_0-rmse:0.08353
# [854]	validation_0-rmse:0.08353
# [855]	validation_0-rmse:0.08353
# [856]	validation_0-rmse:0.08354
# [857]	validation_0-rmse:0.08353
# [858]	validation_0-rmse:0.08354
# [859]	validation_0-rmse:0.08354
# [860]	validation_0-rmse:0.08353
# [861]	validation_0-rmse:0.08353
# [862]	validation_0-rmse:0.08353
# [863]	validation_0-rmse:0.08353
# [864]	validation_0-rmse:0.08353
# [865]	validation_0-rmse:0.08353
# [866]	validation_0-rmse:0.08353
# [867]	validation_0-rmse:0.08352
# [868]	validation_0-rmse:0.08352
# [869]	validation_0-rmse:0.08351
# [870]	validation_0-rmse:0.08351
# [871]	validation_0-rmse:0.08349
# [872]	validation_0-rmse:0.08349
# [873]	validation_0-rmse:0.08349
# [874]	validation_0-rmse:0.08349
# [875]	validation_0-rmse:0.08349
# [876]	validation_0-rmse:0.08348
# [877]	validation_0-rmse:0.08348
# [878]	validation_0-rmse:0.08348
# [879]	validation_0-rmse:0.08348
# [880]	validation_0-rmse:0.08348
# [881]	validation_0-rmse:0.08347
# [882]	validation_0-rmse:0.08347
# [883]	validation_0-rmse:0.08347
# [884]	validation_0-rmse:0.08347
# [885]	validation_0-rmse:0.08347
# [886]	validation_0-rmse:0.08347
# [887]	validation_0-rmse:0.08347
# [888]	validation_0-rmse:0.08347
# [889]	validation_0-rmse:0.08347
# [890]	validation_0-rmse:0.08347
# [891]	validation_0-rmse:0.08347
# [892]	validation_0-rmse:0.08347
# [893]	validation_0-rmse:0.08346
# [894]	validation_0-rmse:0.08346
# [895]	validation_0-rmse:0.08346
# [896]	validation_0-rmse:0.08346
# [897]	validation_0-rmse:0.08346
# [898]	validation_0-rmse:0.08346
# [899]	validation_0-rmse:0.08346
# [900]	validation_0-rmse:0.08346
# [901]	validation_0-rmse:0.08346
# [902]	validation_0-rmse:0.08345
# [903]	validation_0-rmse:0.08345
# [904]	validation_0-rmse:0.08345
# [905]	validation_0-rmse:0.08345
# [906]	validation_0-rmse:0.08345
# [907]	validation_0-rmse:0.08345
# [908]	validation_0-rmse:0.08344
# [909]	validation_0-rmse:0.08344
# [910]	validation_0-rmse:0.08344
# [911]	validation_0-rmse:0.08344
# [912]	validation_0-rmse:0.08344
# [913]	validation_0-rmse:0.08343
# [914]	validation_0-rmse:0.08343
# [915]	validation_0-rmse:0.08344
# [916]	validation_0-rmse:0.08343
# [917]	validation_0-rmse:0.08343
# [918]	validation_0-rmse:0.08343
# [919]	validation_0-rmse:0.08343
# [920]	validation_0-rmse:0.08342
# [921]	validation_0-rmse:0.08343
# [922]	validation_0-rmse:0.08342
# [923]	validation_0-rmse:0.08342
# [924]	validation_0-rmse:0.08342
# [925]	validation_0-rmse:0.08343
# [926]	validation_0-rmse:0.08343
# [927]	validation_0-rmse:0.08343
# [928]	validation_0-rmse:0.08343
# [929]	validation_0-rmse:0.08343
# [930]	validation_0-rmse:0.08343
# [931]	validation_0-rmse:0.08343
# [932]	validation_0-rmse:0.08343
# [933]	validation_0-rmse:0.08343
# [934]	validation_0-rmse:0.08343
# [935]	validation_0-rmse:0.08342
# [936]	validation_0-rmse:0.08342
# [937]	validation_0-rmse:0.08341
# [938]	validation_0-rmse:0.08341
# [939]	validation_0-rmse:0.08341
# [940]	validation_0-rmse:0.08342
# [941]	validation_0-rmse:0.08342
# [942]	validation_0-rmse:0.08342
# [943]	validation_0-rmse:0.08342
# [944]	validation_0-rmse:0.08341
# [945]	validation_0-rmse:0.08341
# [946]	validation_0-rmse:0.08341
# [947]	validation_0-rmse:0.08341
# [948]	validation_0-rmse:0.08340
# [949]	validation_0-rmse:0.08340
# [950]	validation_0-rmse:0.08340
# [951]	validation_0-rmse:0.08340
# [952]	validation_0-rmse:0.08339
# [953]	validation_0-rmse:0.08339
# [954]	validation_0-rmse:0.08338
# [955]	validation_0-rmse:0.08338
# [956]	validation_0-rmse:0.08338
# [957]	validation_0-rmse:0.08338
# [958]	validation_0-rmse:0.08338
# [959]	validation_0-rmse:0.08337
# [960]	validation_0-rmse:0.08337
# [961]	validation_0-rmse:0.08337
# [962]	validation_0-rmse:0.08337
# [963]	validation_0-rmse:0.08336
# [964]	validation_0-rmse:0.08336
# [965]	validation_0-rmse:0.08335
# [966]	validation_0-rmse:0.08335
# [967]	validation_0-rmse:0.08335
# [968]	validation_0-rmse:0.08334
# [969]	validation_0-rmse:0.08334
# [970]	validation_0-rmse:0.08334
# [971]	validation_0-rmse:0.08334
# [972]	validation_0-rmse:0.08334
# [973]	validation_0-rmse:0.08334
# [974]	validation_0-rmse:0.08333
# [975]	validation_0-rmse:0.08333
# [976]	validation_0-rmse:0.08333
# [977]	validation_0-rmse:0.08333
# [978]	validation_0-rmse:0.08333
# [979]	validation_0-rmse:0.08332
# [980]	validation_0-rmse:0.08333
# [981]	validation_0-rmse:0.08332
# [982]	validation_0-rmse:0.08332
# [983]	validation_0-rmse:0.08332
# [984]	validation_0-rmse:0.08332
# [985]	validation_0-rmse:0.08332
# [986]	validation_0-rmse:0.08332
# [987]	validation_0-rmse:0.08332
# [988]	validation_0-rmse:0.08332
# [989]	validation_0-rmse:0.08331
# [990]	validation_0-rmse:0.08331
# [991]	validation_0-rmse:0.08331
# [992]	validation_0-rmse:0.08330
# [993]	validation_0-rmse:0.08329
# [994]	validation_0-rmse:0.08330
# [995]	validation_0-rmse:0.08329
# [996]	validation_0-rmse:0.08329
# [997]	validation_0-rmse:0.08329
# [998]	validation_0-rmse:0.08329
# [999]	validation_0-rmse:0.08329
# [1000]	validation_0-rmse:0.08329
# [1001]	validation_0-rmse:0.08328
# [1002]	validation_0-rmse:0.08328
# [1003]	validation_0-rmse:0.08328
# [1004]	validation_0-rmse:0.08327
# [1005]	validation_0-rmse:0.08327
# [1006]	validation_0-rmse:0.08327
# [1007]	validation_0-rmse:0.08327
# [1008]	validation_0-rmse:0.08327
# [1009]	validation_0-rmse:0.08327
# [1010]	validation_0-rmse:0.08325
# [1011]	validation_0-rmse:0.08324
# [1012]	validation_0-rmse:0.08324
# [1013]	validation_0-rmse:0.08325
# [1014]	validation_0-rmse:0.08324
# [1015]	validation_0-rmse:0.08324
# [1016]	validation_0-rmse:0.08324
# [1017]	validation_0-rmse:0.08324
# [1018]	validation_0-rmse:0.08324
# [1019]	validation_0-rmse:0.08324
# [1020]	validation_0-rmse:0.08324
# [1021]	validation_0-rmse:0.08324
# [1022]	validation_0-rmse:0.08324
# [1023]	validation_0-rmse:0.08324
# [1024]	validation_0-rmse:0.08322
# [1025]	validation_0-rmse:0.08323
# [1026]	validation_0-rmse:0.08323
# [1027]	validation_0-rmse:0.08323
# [1028]	validation_0-rmse:0.08322
# [1029]	validation_0-rmse:0.08322
# [1030]	validation_0-rmse:0.08323
# [1031]	validation_0-rmse:0.08322
# [1032]	validation_0-rmse:0.08322
# [1033]	validation_0-rmse:0.08323
# [1034]	validation_0-rmse:0.08321
# [1035]	validation_0-rmse:0.08321
# [1036]	validation_0-rmse:0.08321
# [1037]	validation_0-rmse:0.08320
# [1038]	validation_0-rmse:0.08320
# [1039]	validation_0-rmse:0.08320
# [1040]	validation_0-rmse:0.08320
# [1041]	validation_0-rmse:0.08320
# [1042]	validation_0-rmse:0.08321
# [1043]	validation_0-rmse:0.08320
# [1044]	validation_0-rmse:0.08319
# [1045]	validation_0-rmse:0.08319
# [1046]	validation_0-rmse:0.08319
# [1047]	validation_0-rmse:0.08318
# [1048]	validation_0-rmse:0.08318
# [1049]	validation_0-rmse:0.08318
# [1050]	validation_0-rmse:0.08318
# [1051]	validation_0-rmse:0.08318
# [1052]	validation_0-rmse:0.08318
# [1053]	validation_0-rmse:0.08317
# [1054]	validation_0-rmse:0.08317
# [1055]	validation_0-rmse:0.08316
# [1056]	validation_0-rmse:0.08316
# [1057]	validation_0-rmse:0.08316
# [1058]	validation_0-rmse:0.08316
# [1059]	validation_0-rmse:0.08316
# [1060]	validation_0-rmse:0.08316
# [1061]	validation_0-rmse:0.08316
# [1062]	validation_0-rmse:0.08316
# [1063]	validation_0-rmse:0.08314
# [1064]	validation_0-rmse:0.08314
# [1065]	validation_0-rmse:0.08314
# [1066]	validation_0-rmse:0.08315
# [1067]	validation_0-rmse:0.08314
# [1068]	validation_0-rmse:0.08314
# [1069]	validation_0-rmse:0.08315
# [1070]	validation_0-rmse:0.08314
# [1071]	validation_0-rmse:0.08314
# [1072]	validation_0-rmse:0.08314
# [1073]	validation_0-rmse:0.08314
# [1074]	validation_0-rmse:0.08314
# [1075]	validation_0-rmse:0.08314
# [1076]	validation_0-rmse:0.08314
# [1077]	validation_0-rmse:0.08314
# [1078]	validation_0-rmse:0.08315
# [1079]	validation_0-rmse:0.08315
# [1080]	validation_0-rmse:0.08314
# [1081]	validation_0-rmse:0.08314
# [1082]	validation_0-rmse:0.08313
# [1083]	validation_0-rmse:0.08312
# [1084]	validation_0-rmse:0.08312
# [1085]	validation_0-rmse:0.08312
# [1086]	validation_0-rmse:0.08312
# [1087]	validation_0-rmse:0.08312
# [1088]	validation_0-rmse:0.08312
# [1089]	validation_0-rmse:0.08312
# [1090]	validation_0-rmse:0.08312
# [1091]	validation_0-rmse:0.08312
# [1092]	validation_0-rmse:0.08313
# [1093]	validation_0-rmse:0.08313
# [1094]	validation_0-rmse:0.08312
# [1095]	validation_0-rmse:0.08312
# [1096]	validation_0-rmse:0.08312
# [1097]	validation_0-rmse:0.08312
# [1098]	validation_0-rmse:0.08312
# [1099]	validation_0-rmse:0.08312
# [1100]	validation_0-rmse:0.08313
# [1101]	validation_0-rmse:0.08311
# [1102]	validation_0-rmse:0.08311
# [1103]	validation_0-rmse:0.08311
# [1104]	validation_0-rmse:0.08311
# [1105]	validation_0-rmse:0.08311
# [1106]	validation_0-rmse:0.08310
# [1107]	validation_0-rmse:0.08309
# [1108]	validation_0-rmse:0.08309
# [1109]	validation_0-rmse:0.08309
# [1110]	validation_0-rmse:0.08309
# [1111]	validation_0-rmse:0.08309
# [1112]	validation_0-rmse:0.08309
# [1113]	validation_0-rmse:0.08309
# [1114]	validation_0-rmse:0.08309
# [1115]	validation_0-rmse:0.08309
# [1116]	validation_0-rmse:0.08309
# [1117]	validation_0-rmse:0.08308
# [1118]	validation_0-rmse:0.08308
# [1119]	validation_0-rmse:0.08308
# [1120]	validation_0-rmse:0.08308
# [1121]	validation_0-rmse:0.08308
# [1122]	validation_0-rmse:0.08308
# [1123]	validation_0-rmse:0.08308
# [1124]	validation_0-rmse:0.08307
# [1125]	validation_0-rmse:0.08308
# [1126]	validation_0-rmse:0.08308
# [1127]	validation_0-rmse:0.08307
# [1128]	validation_0-rmse:0.08307
# [1129]	validation_0-rmse:0.08307
# [1130]	validation_0-rmse:0.08307
# [1131]	validation_0-rmse:0.08307
# [1132]	validation_0-rmse:0.08307
# [1133]	validation_0-rmse:0.08307
# [1134]	validation_0-rmse:0.08306
# [1135]	validation_0-rmse:0.08306
# [1136]	validation_0-rmse:0.08306
# [1137]	validation_0-rmse:0.08306
# [1138]	validation_0-rmse:0.08305
# [1139]	validation_0-rmse:0.08305
# [1140]	validation_0-rmse:0.08305
# [1141]	validation_0-rmse:0.08304
# [1142]	validation_0-rmse:0.08304
# [1143]	validation_0-rmse:0.08304
# [1144]	validation_0-rmse:0.08303
# [1145]	validation_0-rmse:0.08303
# [1146]	validation_0-rmse:0.08303
# [1147]	validation_0-rmse:0.08303
# [1148]	validation_0-rmse:0.08303
# [1149]	validation_0-rmse:0.08303
# [1150]	validation_0-rmse:0.08303
# [1151]	validation_0-rmse:0.08303
# [1152]	validation_0-rmse:0.08302
# [1153]	validation_0-rmse:0.08303
# [1154]	validation_0-rmse:0.08302
# [1155]	validation_0-rmse:0.08303
# [1156]	validation_0-rmse:0.08303
# [1157]	validation_0-rmse:0.08302
# [1158]	validation_0-rmse:0.08302
# [1159]	validation_0-rmse:0.08302
# [1160]	validation_0-rmse:0.08302
# [1161]	validation_0-rmse:0.08302
# [1162]	validation_0-rmse:0.08302
# [1163]	validation_0-rmse:0.08302
# [1164]	validation_0-rmse:0.08301
# [1165]	validation_0-rmse:0.08302
# [1166]	validation_0-rmse:0.08302
# [1167]	validation_0-rmse:0.08302
# [1168]	validation_0-rmse:0.08301
# [1169]	validation_0-rmse:0.08301
# [1170]	validation_0-rmse:0.08301
# [1171]	validation_0-rmse:0.08301
# [1172]	validation_0-rmse:0.08301
# [1173]	validation_0-rmse:0.08301
# [1174]	validation_0-rmse:0.08301
# [1175]	validation_0-rmse:0.08301
# [1176]	validation_0-rmse:0.08301
# [1177]	validation_0-rmse:0.08301
# [1178]	validation_0-rmse:0.08301
# [1179]	validation_0-rmse:0.08301
# [1180]	validation_0-rmse:0.08301
# [1181]	validation_0-rmse:0.08301
# [1182]	validation_0-rmse:0.08301
# [1183]	validation_0-rmse:0.08301
# [1184]	validation_0-rmse:0.08301
# [1185]	validation_0-rmse:0.08301
# [1186]	validation_0-rmse:0.08301
# [1187]	validation_0-rmse:0.08301
# [1188]	validation_0-rmse:0.08301
# [1189]	validation_0-rmse:0.08301
# [1190]	validation_0-rmse:0.08301
# [1191]	validation_0-rmse:0.08301
# [1192]	validation_0-rmse:0.08301
# [1193]	validation_0-rmse:0.08301
# [1194]	validation_0-rmse:0.08301
# [1195]	validation_0-rmse:0.08300
# [1196]	validation_0-rmse:0.08301
# [1197]	validation_0-rmse:0.08300
# [1198]	validation_0-rmse:0.08300
# [1199]	validation_0-rmse:0.08301
# [1200]	validation_0-rmse:0.08300
# [1201]	validation_0-rmse:0.08300
# [1202]	validation_0-rmse:0.08300
# [1203]	validation_0-rmse:0.08300
# [1204]	validation_0-rmse:0.08300
# [1205]	validation_0-rmse:0.08300
# [1206]	validation_0-rmse:0.08300
# [1207]	validation_0-rmse:0.08300
# [1208]	validation_0-rmse:0.08299
# [1209]	validation_0-rmse:0.08299
# [1210]	validation_0-rmse:0.08299
# [1211]	validation_0-rmse:0.08299
# [1212]	validation_0-rmse:0.08299
# [1213]	validation_0-rmse:0.08299
# [1214]	validation_0-rmse:0.08299
# [1215]	validation_0-rmse:0.08298
# [1216]	validation_0-rmse:0.08299
# [1217]	validation_0-rmse:0.08299
# [1218]	validation_0-rmse:0.08298
# [1219]	validation_0-rmse:0.08298
# [1220]	validation_0-rmse:0.08298
# [1221]	validation_0-rmse:0.08298
# [1222]	validation_0-rmse:0.08297
# [1223]	validation_0-rmse:0.08296
# [1224]	validation_0-rmse:0.08295
# [1225]	validation_0-rmse:0.08295
# [1226]	validation_0-rmse:0.08295
# [1227]	validation_0-rmse:0.08295
# [1228]	validation_0-rmse:0.08295
# [1229]	validation_0-rmse:0.08294
# [1230]	validation_0-rmse:0.08294
# [1231]	validation_0-rmse:0.08294
# [1232]	validation_0-rmse:0.08294
# [1233]	validation_0-rmse:0.08294
# [1234]	validation_0-rmse:0.08294
# [1235]	validation_0-rmse:0.08294
# [1236]	validation_0-rmse:0.08294
# [1237]	validation_0-rmse:0.08293
# [1238]	validation_0-rmse:0.08293
# [1239]	validation_0-rmse:0.08293
# [1240]	validation_0-rmse:0.08293
# [1241]	validation_0-rmse:0.08293
# [1242]	validation_0-rmse:0.08293
# [1243]	validation_0-rmse:0.08292
# [1244]	validation_0-rmse:0.08292
# [1245]	validation_0-rmse:0.08292
# [1246]	validation_0-rmse:0.08292
# [1247]	validation_0-rmse:0.08293
# [1248]	validation_0-rmse:0.08293
# [1249]	validation_0-rmse:0.08293
# [1250]	validation_0-rmse:0.08293
# [1251]	validation_0-rmse:0.08293
# [1252]	validation_0-rmse:0.08293
# [1253]	validation_0-rmse:0.08293
# [1254]	validation_0-rmse:0.08293
# [1255]	validation_0-rmse:0.08292
# [1256]	validation_0-rmse:0.08292
# [1257]	validation_0-rmse:0.08292
# [1258]	validation_0-rmse:0.08292
# [1259]	validation_0-rmse:0.08292
# [1260]	validation_0-rmse:0.08292
# [1261]	validation_0-rmse:0.08292
# [1262]	validation_0-rmse:0.08292
# [1263]	validation_0-rmse:0.08292
# [1264]	validation_0-rmse:0.08292
# [1265]	validation_0-rmse:0.08291
# [1266]	validation_0-rmse:0.08289
# [1267]	validation_0-rmse:0.08289
# [1268]	validation_0-rmse:0.08289
# [1269]	validation_0-rmse:0.08289
# [1270]	validation_0-rmse:0.08289
# [1271]	validation_0-rmse:0.08288
# [1272]	validation_0-rmse:0.08288
# [1273]	validation_0-rmse:0.08288
# [1274]	validation_0-rmse:0.08288
# [1275]	validation_0-rmse:0.08288
# [1276]	validation_0-rmse:0.08288
# [1277]	validation_0-rmse:0.08288
# [1278]	validation_0-rmse:0.08288
# [1279]	validation_0-rmse:0.08287
# [1280]	validation_0-rmse:0.08287
# [1281]	validation_0-rmse:0.08287
# [1282]	validation_0-rmse:0.08286
# [1283]	validation_0-rmse:0.08286
# [1284]	validation_0-rmse:0.08286
# [1285]	validation_0-rmse:0.08286
# [1286]	validation_0-rmse:0.08285
# [1287]	validation_0-rmse:0.08285
# [1288]	validation_0-rmse:0.08285
# [1289]	validation_0-rmse:0.08285
# [1290]	validation_0-rmse:0.08285
# [1291]	validation_0-rmse:0.08285
# [1292]	validation_0-rmse:0.08285
# [1293]	validation_0-rmse:0.08284
# [1294]	validation_0-rmse:0.08284
# [1295]	validation_0-rmse:0.08284
# [1296]	validation_0-rmse:0.08284
# [1297]	validation_0-rmse:0.08284
# [1298]	validation_0-rmse:0.08284
# [1299]	validation_0-rmse:0.08284
# [1300]	validation_0-rmse:0.08284
# [1301]	validation_0-rmse:0.08284
# [1302]	validation_0-rmse:0.08284
# [1303]	validation_0-rmse:0.08284
# [1304]	validation_0-rmse:0.08284
# [1305]	validation_0-rmse:0.08284
# [1306]	validation_0-rmse:0.08283
# [1307]	validation_0-rmse:0.08283
# [1308]	validation_0-rmse:0.08283
# [1309]	validation_0-rmse:0.08283
# [1310]	validation_0-rmse:0.08283
# [1311]	validation_0-rmse:0.08283
# [1312]	validation_0-rmse:0.08283
# [1313]	validation_0-rmse:0.08282
# [1314]	validation_0-rmse:0.08283
# [1315]	validation_0-rmse:0.08282
# [1316]	validation_0-rmse:0.08282
# [1317]	validation_0-rmse:0.08282
# [1318]	validation_0-rmse:0.08282
# [1319]	validation_0-rmse:0.08281
# [1320]	validation_0-rmse:0.08281
# [1321]	validation_0-rmse:0.08281
# [1322]	validation_0-rmse:0.08281
# [1323]	validation_0-rmse:0.08281
# [1324]	validation_0-rmse:0.08281
# [1325]	validation_0-rmse:0.08281
# [1326]	validation_0-rmse:0.08281
# [1327]	validation_0-rmse:0.08281
# [1328]	validation_0-rmse:0.08281
# [1329]	validation_0-rmse:0.08280
# [1330]	validation_0-rmse:0.08280
# [1331]	validation_0-rmse:0.08280
# [1332]	validation_0-rmse:0.08280
# [1333]	validation_0-rmse:0.08280
# [1334]	validation_0-rmse:0.08280
# [1335]	validation_0-rmse:0.08280
# [1336]	validation_0-rmse:0.08280
# [1337]	validation_0-rmse:0.08280
# [1338]	validation_0-rmse:0.08280
# [1339]	validation_0-rmse:0.08280
# [1340]	validation_0-rmse:0.08280
# [1341]	validation_0-rmse:0.08280
# [1342]	validation_0-rmse:0.08280
# [1343]	validation_0-rmse:0.08279
# [1344]	validation_0-rmse:0.08279
# [1345]	validation_0-rmse:0.08279
# [1346]	validation_0-rmse:0.08279
# [1347]	validation_0-rmse:0.08279
# [1348]	validation_0-rmse:0.08279
# [1349]	validation_0-rmse:0.08279
# [1350]	validation_0-rmse:0.08279
# [1351]	validation_0-rmse:0.08279
# [1352]	validation_0-rmse:0.08279
# [1353]	validation_0-rmse:0.08279
# [1354]	validation_0-rmse:0.08278
# [1355]	validation_0-rmse:0.08278
# [1356]	validation_0-rmse:0.08278
# [1357]	validation_0-rmse:0.08278
# [1358]	validation_0-rmse:0.08278
# [1359]	validation_0-rmse:0.08278
# [1360]	validation_0-rmse:0.08278
# [1361]	validation_0-rmse:0.08278
# [1362]	validation_0-rmse:0.08278
# [1363]	validation_0-rmse:0.08277
# [1364]	validation_0-rmse:0.08277
# [1365]	validation_0-rmse:0.08277
# [1366]	validation_0-rmse:0.08277
# [1367]	validation_0-rmse:0.08277
# [1368]	validation_0-rmse:0.08277
# [1369]	validation_0-rmse:0.08277
# [1370]	validation_0-rmse:0.08277
# [1371]	validation_0-rmse:0.08277
# [1372]	validation_0-rmse:0.08277
# [1373]	validation_0-rmse:0.08277
# [1374]	validation_0-rmse:0.08277
# [1375]	validation_0-rmse:0.08277
# [1376]	validation_0-rmse:0.08277
# [1377]	validation_0-rmse:0.08277
# [1378]	validation_0-rmse:0.08277
# [1379]	validation_0-rmse:0.08276
# [1380]	validation_0-rmse:0.08276
# [1381]	validation_0-rmse:0.08276
# [1382]	validation_0-rmse:0.08276
# [1383]	validation_0-rmse:0.08276
# [1384]	validation_0-rmse:0.08276
# [1385]	validation_0-rmse:0.08276
# [1386]	validation_0-rmse:0.08276
# [1387]	validation_0-rmse:0.08276
# [1388]	validation_0-rmse:0.08276
# [1389]	validation_0-rmse:0.08275
# [1390]	validation_0-rmse:0.08275
# [1391]	validation_0-rmse:0.08275
# [1392]	validation_0-rmse:0.08275
# [1393]	validation_0-rmse:0.08274
# [1394]	validation_0-rmse:0.08274
# [1395]	validation_0-rmse:0.08274
# [1396]	validation_0-rmse:0.08274
# [1397]	validation_0-rmse:0.08273
# [1398]	validation_0-rmse:0.08273
# [1399]	validation_0-rmse:0.08273
# [1400]	validation_0-rmse:0.08273
# [1401]	validation_0-rmse:0.08273
# [1402]	validation_0-rmse:0.08273
# [1403]	validation_0-rmse:0.08272
# [1404]	validation_0-rmse:0.08272
# [1405]	validation_0-rmse:0.08272
# [1406]	validation_0-rmse:0.08271
# [1407]	validation_0-rmse:0.08271
# [1408]	validation_0-rmse:0.08271
# [1409]	validation_0-rmse:0.08271
# [1410]	validation_0-rmse:0.08271
# [1411]	validation_0-rmse:0.08271
# [1412]	validation_0-rmse:0.08271
# [1413]	validation_0-rmse:0.08270
# [1414]	validation_0-rmse:0.08271
# [1415]	validation_0-rmse:0.08271
# [1416]	validation_0-rmse:0.08270
# [1417]	validation_0-rmse:0.08270
# [1418]	validation_0-rmse:0.08271
# [1419]	validation_0-rmse:0.08270
# [1420]	validation_0-rmse:0.08270
# [1421]	validation_0-rmse:0.08270
# [1422]	validation_0-rmse:0.08270
# [1423]	validation_0-rmse:0.08270
# [1424]	validation_0-rmse:0.08270
# [1425]	validation_0-rmse:0.08270
# [1426]	validation_0-rmse:0.08270
# [1427]	validation_0-rmse:0.08270
# [1428]	validation_0-rmse:0.08270
# [1429]	validation_0-rmse:0.08269
# [1430]	validation_0-rmse:0.08269
# [1431]	validation_0-rmse:0.08269
# [1432]	validation_0-rmse:0.08269
# [1433]	validation_0-rmse:0.08269
# [1434]	validation_0-rmse:0.08269
# [1435]	validation_0-rmse:0.08269
# [1436]	validation_0-rmse:0.08269
# [1437]	validation_0-rmse:0.08269
# [1438]	validation_0-rmse:0.08269
# [1439]	validation_0-rmse:0.08269
# [1440]	validation_0-rmse:0.08268
# [1441]	validation_0-rmse:0.08268
# [1442]	validation_0-rmse:0.08268
# [1443]	validation_0-rmse:0.08268
# [1444]	validation_0-rmse:0.08267
# [1445]	validation_0-rmse:0.08267
# [1446]	validation_0-rmse:0.08267
# [1447]	validation_0-rmse:0.08267
# [1448]	validation_0-rmse:0.08267
# [1449]	validation_0-rmse:0.08267
# [1450]	validation_0-rmse:0.08267
# [1451]	validation_0-rmse:0.08267
# [1452]	validation_0-rmse:0.08266
# [1453]	validation_0-rmse:0.08266
# [1454]	validation_0-rmse:0.08266
# [1455]	validation_0-rmse:0.08266
# [1456]	validation_0-rmse:0.08265
# [1457]	validation_0-rmse:0.08265
# [1458]	validation_0-rmse:0.08265
# [1459]	validation_0-rmse:0.08265
# [1460]	validation_0-rmse:0.08264
# [1461]	validation_0-rmse:0.08264
# [1462]	validation_0-rmse:0.08264
# [1463]	validation_0-rmse:0.08264
# [1464]	validation_0-rmse:0.08264
# [1465]	validation_0-rmse:0.08264
# [1466]	validation_0-rmse:0.08264
# [1467]	validation_0-rmse:0.08264
# [1468]	validation_0-rmse:0.08264
# [1469]	validation_0-rmse:0.08264
# [1470]	validation_0-rmse:0.08264
# [1471]	validation_0-rmse:0.08264
# [1472]	validation_0-rmse:0.08264
# [1473]	validation_0-rmse:0.08264
# [1474]	validation_0-rmse:0.08264
# [1475]	validation_0-rmse:0.08263
# [1476]	validation_0-rmse:0.08263
# [1477]	validation_0-rmse:0.08263
# [1478]	validation_0-rmse:0.08263
# [1479]	validation_0-rmse:0.08263
# [1480]	validation_0-rmse:0.08263
# [1481]	validation_0-rmse:0.08263
# [1482]	validation_0-rmse:0.08263
# [1483]	validation_0-rmse:0.08263
# [1484]	validation_0-rmse:0.08262
# [1485]	validation_0-rmse:0.08262
# [1486]	validation_0-rmse:0.08262
# [1487]	validation_0-rmse:0.08263
# ...
# [1555]	validation_0-rmse:0.08256
# [1556]	validation_0-rmse:0.08256
# [1557]	validation_0-rmse:0.08255
# [1558]	validation_0-rmse:0.08256
# [1559]	validation_0-rmse:0.08255
# [1560]	validation_0-rmse:0.08255
# [1561]	validation_0-rmse:0.08255
# [1562]	validation_0-rmse:0.08255
# [1563]	validation_0-rmse:0.08255
# [1564]	validation_0-rmse:0.08255
# [1565]	validation_0-rmse:0.08255
# [1566]	validation_0-rmse:0.08255
# [1567]	validation_0-rmse:0.08255
# [1568]	validation_0-rmse:0.08254
# [1569]	validation_0-rmse:0.08255
# [1570]	validation_0-rmse:0.08254
# [1571]	validation_0-rmse:0.08254
# [1572]	validation_0-rmse:0.08254
# [1573]	validation_0-rmse:0.08254
# [1574]	validation_0-rmse:0.08254
# [1575]	validation_0-rmse:0.08254
# [1576]	validation_0-rmse:0.08254
# [1577]	validation_0-rmse:0.08254
# [1578]	validation_0-rmse:0.08254
# [1579]	validation_0-rmse:0.08254
# [1580]	validation_0-rmse:0.08254
# [1581]	validation_0-rmse:0.08254
# [1582]	validation_0-rmse:0.08254
# [1583]	validation_0-rmse:0.08254
# [1584]	validation_0-rmse:0.08254
# [1585]	validation_0-rmse:0.08254
# [1586]	validation_0-rmse:0.08253
# [1587]	validation_0-rmse:0.08253
# [1588]	validation_0-rmse:0.08254
# [1589]	validation_0-rmse:0.08253
# [1590]	validation_0-rmse:0.08254
# [1591]	validation_0-rmse:0.08254
# [1592]	validation_0-rmse:0.08254
# [1593]	validation_0-rmse:0.08254
# [1594]	validation_0-rmse:0.08254
# [1595]	validation_0-rmse:0.08254
# [1596]	validation_0-rmse:0.08254
# [1597]	validation_0-rmse:0.08254
# [1598]	validation_0-rmse:0.08254
# [1599]	validation_0-rmse:0.08253
# [1600]	validation_0-rmse:0.08253
# [1601]	validation_0-rmse:0.08253
# [1602]	validation_0-rmse:0.08253
# [1603]	validation_0-rmse:0.08253
# [1604]	validation_0-rmse:0.08253
# [1605]	validation_0-rmse:0.08253
# [1606]	validation_0-rmse:0.08253
# [1607]	validation_0-rmse:0.08252
# [1608]	validation_0-rmse:0.08252
# [1609]	validation_0-rmse:0.08252
# [1610]	validation_0-rmse:0.08252
# [1611]	validation_0-rmse:0.08252
# [1612]	validation_0-rmse:0.08252
# [1613]	validation_0-rmse:0.08252
# [1614]	validation_0-rmse:0.08252
# [1615]	validation_0-rmse:0.08252
# [1616]	validation_0-rmse:0.08252
# [1617]	validation_0-rmse:0.08251
# [1618]	validation_0-rmse:0.08251
# [1619]	validation_0-rmse:0.08251
# [1620]	validation_0-rmse:0.08251
# [1621]	validation_0-rmse:0.08251
# [1622]	validation_0-rmse:0.08250
# [1623]	validation_0-rmse:0.08250
# [1624]	validation_0-rmse:0.08250
# [1625]	validation_0-rmse:0.08250
# [1626]	validation_0-rmse:0.08250
# [1627]	validation_0-rmse:0.08250
# [1628]	validation_0-rmse:0.08250
# [1629]	validation_0-rmse:0.08250
# [1630]	validation_0-rmse:0.08250
# [1631]	validation_0-rmse:0.08250
# [1632]	validation_0-rmse:0.08250
# [1633]	validation_0-rmse:0.08250
# [1634]	validation_0-rmse:0.08250
# [1635]	validation_0-rmse:0.08249
# [1636]	validation_0-rmse:0.08249
# [1637]	validation_0-rmse:0.08249
# [1638]	validation_0-rmse:0.08249
# [1639]	validation_0-rmse:0.08249
# [1640]	validation_0-rmse:0.08250
# [1641]	validation_0-rmse:0.08249
# [1642]	validation_0-rmse:0.08249
# [1643]	validation_0-rmse:0.08249
# [1644]	validation_0-rmse:0.08249
# [1645]	validation_0-rmse:0.08249
# [1646]	validation_0-rmse:0.08249
# [1647]	validation_0-rmse:0.08249
# [1648]	validation_0-rmse:0.08249
# [1649]	validation_0-rmse:0.08249
# [1650]	validation_0-rmse:0.08249
# [1651]	validation_0-rmse:0.08249
# [1652]	validation_0-rmse:0.08249
# [1653]	validation_0-rmse:0.08249
# [1654]	validation_0-rmse:0.08249
# [1655]	validation_0-rmse:0.08249
# [1656]	validation_0-rmse:0.08249
# [1657]	validation_0-rmse:0.08248
# [1658]	validation_0-rmse:0.08248
# [1659]	validation_0-rmse:0.08248
# [1660]	validation_0-rmse:0.08248
# [1661]	validation_0-rmse:0.08247
# [1662]	validation_0-rmse:0.08247
# [1663]	validation_0-rmse:0.08247
# [1664]	validation_0-rmse:0.08246
# [1665]	validation_0-rmse:0.08246
# [1666]	validation_0-rmse:0.08245
# [1667]	validation_0-rmse:0.08245
# [1668]	validation_0-rmse:0.08245
# [1669]	validation_0-rmse:0.08245
# [1670]	validation_0-rmse:0.08244
# [1671]	validation_0-rmse:0.08244
# [1672]	validation_0-rmse:0.08244
# [1673]	validation_0-rmse:0.08244
# [1674]	validation_0-rmse:0.08244
# [1675]	validation_0-rmse:0.08244
# [1676]	validation_0-rmse:0.08244
# [1677]	validation_0-rmse:0.08244
# [1678]	validation_0-rmse:0.08244
# [1679]	validation_0-rmse:0.08244
# [1680]	validation_0-rmse:0.08244
# [1681]	validation_0-rmse:0.08243
# [1682]	validation_0-rmse:0.08243
# [1683]	validation_0-rmse:0.08243
# [1684]	validation_0-rmse:0.08243
# [1685]	validation_0-rmse:0.08243
# [1686]	validation_0-rmse:0.08243
# [1687]	validation_0-rmse:0.08243
# [1688]	validation_0-rmse:0.08243
# [1689]	validation_0-rmse:0.08243
# [1690]	validation_0-rmse:0.08243
# [1691]	validation_0-rmse:0.08243
# [1692]	validation_0-rmse:0.08243
# [1693]	validation_0-rmse:0.08243
# [1694]	validation_0-rmse:0.08243
# [1695]	validation_0-rmse:0.08243
# [1696]	validation_0-rmse:0.08243
# [1697]	validation_0-rmse:0.08242
# [1698]	validation_0-rmse:0.08242
# [1699]	validation_0-rmse:0.08242
# [1700]	validation_0-rmse:0.08242
# [1701]	validation_0-rmse:0.08242
# [1702]	validation_0-rmse:0.08242
# [1703]	validation_0-rmse:0.08242
# [1704]	validation_0-rmse:0.08242
# [1705]	validation_0-rmse:0.08241
# [1706]	validation_0-rmse:0.08241
# [1707]	validation_0-rmse:0.08241
# [1708]	validation_0-rmse:0.08241
# [1709]	validation_0-rmse:0.08241
# [1710]	validation_0-rmse:0.08241
# [1711]	validation_0-rmse:0.08241
# [1712]	validation_0-rmse:0.08241
# [1713]	validation_0-rmse:0.08240
# [1714]	validation_0-rmse:0.08240
# [1715]	validation_0-rmse:0.08240
# [1716]	validation_0-rmse:0.08240
# [1717]	validation_0-rmse:0.08240
# [1718]	validation_0-rmse:0.08240
# [1719]	validation_0-rmse:0.08240
# [1720]	validation_0-rmse:0.08240
# [1721]	validation_0-rmse:0.08240
# [1722]	validation_0-rmse:0.08240
# [1723]	validation_0-rmse:0.08240
# [1724]	validation_0-rmse:0.08240
# [1725]	validation_0-rmse:0.08240
# [1726]	validation_0-rmse:0.08240
# [1727]	validation_0-rmse:0.08240
# [1728]	validation_0-rmse:0.08240
# [1729]	validation_0-rmse:0.08240
# [1730]	validation_0-rmse:0.08240
# [1731]	validation_0-rmse:0.08240
# [1732]	validation_0-rmse:0.08240
# [1733]	validation_0-rmse:0.08240
# [1734]	validation_0-rmse:0.08240
# [1735]	validation_0-rmse:0.08240
# [1736]	validation_0-rmse:0.08240
# [1737]	validation_0-rmse:0.08240
# [1738]	validation_0-rmse:0.08240
# [1739]	validation_0-rmse:0.08240
# [1740]	validation_0-rmse:0.08240
# [1741]	validation_0-rmse:0.08240
# [1742]	validation_0-rmse:0.08239
# [1743]	validation_0-rmse:0.08238
# [1744]	validation_0-rmse:0.08239
# [1745]	validation_0-rmse:0.08239
# [1746]	validation_0-rmse:0.08239
# [1747]	validation_0-rmse:0.08238
# [1748]	validation_0-rmse:0.08238
# [1749]	validation_0-rmse:0.08238
# [1750]	validation_0-rmse:0.08237
# [1751]	validation_0-rmse:0.08237
# [1752]	validation_0-rmse:0.08237
# [1753]	validation_0-rmse:0.08236
# [1754]	validation_0-rmse:0.08235
# [1755]	validation_0-rmse:0.08235
# [1756]	validation_0-rmse:0.08235
# [1757]	validation_0-rmse:0.08235
# [1758]	validation_0-rmse:0.08235
# [1759]	validation_0-rmse:0.08234
# [1760]	validation_0-rmse:0.08234
# [1761]	validation_0-rmse:0.08234
# [1762]	validation_0-rmse:0.08234
# [1763]	validation_0-rmse:0.08234
# [1764]	validation_0-rmse:0.08234
# [1765]	validation_0-rmse:0.08234
# [1766]	validation_0-rmse:0.08233
# [1767]	validation_0-rmse:0.08232
# [1768]	validation_0-rmse:0.08232
# [1769]	validation_0-rmse:0.08232
# [1770]	validation_0-rmse:0.08232
# [1771]	validation_0-rmse:0.08231
# [1772]	validation_0-rmse:0.08231
# [1773]	validation_0-rmse:0.08231
# [1774]	validation_0-rmse:0.08231
# [1775]	validation_0-rmse:0.08231
# [1776]	validation_0-rmse:0.08231
# [1777]	validation_0-rmse:0.08231
# [1778]	validation_0-rmse:0.08231
# [1779]	validation_0-rmse:0.08230
# [1780]	validation_0-rmse:0.08230
# [1781]	validation_0-rmse:0.08230
# [1782]	validation_0-rmse:0.08230
# [1783]	validation_0-rmse:0.08230
# [1784]	validation_0-rmse:0.08230
# [1785]	validation_0-rmse:0.08230
# [1786]	validation_0-rmse:0.08230
# [1787]	validation_0-rmse:0.08230
# [1788]	validation_0-rmse:0.08229
# [1789]	validation_0-rmse:0.08229
# [1790]	validation_0-rmse:0.08229
# [1791]	validation_0-rmse:0.08229
# [1792]	validation_0-rmse:0.08229
# [1793]	validation_0-rmse:0.08228
# [1794]	validation_0-rmse:0.08228
# [1795]	validation_0-rmse:0.08227
# [1796]	validation_0-rmse:0.08227
# [1797]	validation_0-rmse:0.08227
# [1798]	validation_0-rmse:0.08227
# [1799]	validation_0-rmse:0.08227
# [1800]	validation_0-rmse:0.08227
# [1801]	validation_0-rmse:0.08227
# [1802]	validation_0-rmse:0.08227
# [1803]	validation_0-rmse:0.08227
# [1804]	validation_0-rmse:0.08227
# [1805]	validation_0-rmse:0.08227
# [1806]	validation_0-rmse:0.08226
# [1807]	validation_0-rmse:0.08226
# [1808]	validation_0-rmse:0.08226
# [1809]	validation_0-rmse:0.08226
# [1810]	validation_0-rmse:0.08226
# [1811]	validation_0-rmse:0.08225
# [1812]	validation_0-rmse:0.08225
# [1813]	validation_0-rmse:0.08225
# [1814]	validation_0-rmse:0.08225
# [1815]	validation_0-rmse:0.08225
# [1816]	validation_0-rmse:0.08225
# [1817]	validation_0-rmse:0.08225
# [1818]	validation_0-rmse:0.08225
# [1819]	validation_0-rmse:0.08225
# [1820]	validation_0-rmse:0.08225
# [1821]	validation_0-rmse:0.08225
# [1822]	validation_0-rmse:0.08225
# [1823]	validation_0-rmse:0.08224
# [1824]	validation_0-rmse:0.08224
# [1825]	validation_0-rmse:0.08224
# [1826]	validation_0-rmse:0.08224
# [1827]	validation_0-rmse:0.08224
# [1828]	validation_0-rmse:0.08224
# [1829]	validation_0-rmse:0.08224
# [1830]	validation_0-rmse:0.08224
# [1831]	validation_0-rmse:0.08224
# [1832]	validation_0-rmse:0.08224
# [1833]	validation_0-rmse:0.08224
# [1834]	validation_0-rmse:0.08224
# [1835]	validation_0-rmse:0.08224
# [1836]	validation_0-rmse:0.08224
# [1837]	validation_0-rmse:0.08223
# [1838]	validation_0-rmse:0.08223
# [1839]	validation_0-rmse:0.08223
# [1840]	validation_0-rmse:0.08223
# [1841]	validation_0-rmse:0.08223
# [1842]	validation_0-rmse:0.08223
# [1843]	validation_0-rmse:0.08223
# [1844]	validation_0-rmse:0.08223
# [1845]	validation_0-rmse:0.08222
# [1846]	validation_0-rmse:0.08222
# [1847]	validation_0-rmse:0.08222
# [1848]	validation_0-rmse:0.08222
# [1849]	validation_0-rmse:0.08223
# [1850]	validation_0-rmse:0.08223
# [1851]	validation_0-rmse:0.08222
# [1852]	validation_0-rmse:0.08222
# [1853]	validation_0-rmse:0.08222
# [1854]	validation_0-rmse:0.08222
# [1855]	validation_0-rmse:0.08222
# [1856]	validation_0-rmse:0.08222
# [1857]	validation_0-rmse:0.08221
# [1858]	validation_0-rmse:0.08221
# [1859]	validation_0-rmse:0.08221
# [1860]	validation_0-rmse:0.08221
# [1861]	validation_0-rmse:0.08221
# [1862]	validation_0-rmse:0.08221
# [1863]	validation_0-rmse:0.08221
# [1864]	validation_0-rmse:0.08221
# [1865]	validation_0-rmse:0.08221
# [1866]	validation_0-rmse:0.08221
# [1867]	validation_0-rmse:0.08221
# [1868]	validation_0-rmse:0.08221
# [1869]	validation_0-rmse:0.08221
# [1870]	validation_0-rmse:0.08221
# [1949]	validation_0-rmse:0.08217
# [1950]	validation_0-rmse:0.08217
# [1951]	validation_0-rmse:0.08217
# [1952]	validation_0-rmse:0.08217
# [1953]	validation_0-rmse:0.08218
# [1954]	validation_0-rmse:0.08217
# [1955]	validation_0-rmse:0.08217
# [1956]	validation_0-rmse:0.08217
# [1957]	validation_0-rmse:0.08217
# [1958]	validation_0-rmse:0.08217
# [1959]	validation_0-rmse:0.08217
# [1960]	validation_0-rmse:0.08217
# [1961]	validation_0-rmse:0.08217
# [1962]	validation_0-rmse:0.08217
# [1963]	validation_0-rmse:0.08217
# [1964]	validation_0-rmse:0.08217
# [1965]	validation_0-rmse:0.08217
# [1966]	validation_0-rmse:0.08217
# [1967]	validation_0-rmse:0.08217
# [1968]	validation_0-rmse:0.08217
# [1969]	validation_0-rmse:0.08217
# [1970]	validation_0-rmse:0.08217
# [1971]	validation_0-rmse:0.08217
# [1972]	validation_0-rmse:0.08217
# [1973]	validation_0-rmse:0.08217
# [1974]	validation_0-rmse:0.08217
# [1975]	validation_0-rmse:0.08217
# [1976]	validation_0-rmse:0.08217
# [1977]	validation_0-rmse:0.08217
# [1978]	validation_0-rmse:0.08216
# [1979]	validation_0-rmse:0.08216
# [1980]	validation_0-rmse:0.08216
# [1981]	validation_0-rmse:0.08216
# [1982]	validation_0-rmse:0.08216
# [1983]	validation_0-rmse:0.08216
# [1984]	validation_0-rmse:0.08216
# [1985]	validation_0-rmse:0.08216
# [1986]	validation_0-rmse:0.08216
# [1987]	validation_0-rmse:0.08216
# [1988]	validation_0-rmse:0.08216
# [1989]	validation_0-rmse:0.08216
# [1990]	validation_0-rmse:0.08216
# [1991]	validation_0-rmse:0.08216
# [1992]	validation_0-rmse:0.08216
# [1993]	validation_0-rmse:0.08216
# [1994]	validation_0-rmse:0.08216
# [1995]	validation_0-rmse:0.08216
# [1996]	validation_0-rmse:0.08216
# [1997]	validation_0-rmse:0.08216
# [1998]	validation_0-rmse:0.08216
# [1999]	validation_0-rmse:0.08216
# [2000]	validation_0-rmse:0.08216
# [2001]	validation_0-rmse:0.08216
# [2002]	validation_0-rmse:0.08216
# [2003]	validation_0-rmse:0.08216
# [2004]	validation_0-rmse:0.08216
# [2005]	validation_0-rmse:0.08216
# [2006]	validation_0-rmse:0.08216
# [2007]	validation_0-rmse:0.08216
# [2008]	validation_0-rmse:0.08216
# [2009]	validation_0-rmse:0.08217
# [2010]	validation_0-rmse:0.08217
# [2011]	validation_0-rmse:0.08217
# [2012]	validation_0-rmse:0.08217
# [2013]	validation_0-rmse:0.08217
# [2014]	validation_0-rmse:0.08217
# [2015]	validation_0-rmse:0.08217
# [2016]	validation_0-rmse:0.08217
# [2017]	validation_0-rmse:0.08217
# [2018]	validation_0-rmse:0.08217
# [2019]	validation_0-rmse:0.08217
# [2020]	validation_0-rmse:0.08217
# [2021]	validation_0-rmse:0.08217
# [2022]	validation_0-rmse:0.08217
# [2023]	validation_0-rmse:0.08217
# [2024]	validation_0-rmse:0.08217
# [2025]	validation_0-rmse:0.08217
# [2026]	validation_0-rmse:0.08217
# [2027]	validation_0-rmse:0.08216
# [2028]	validation_0-rmse:0.08216
# [2029]	validation_0-rmse:0.08216
# [2030]	validation_0-rmse:0.08217
# [2031]	validation_0-rmse:0.08217
# [2032]	validation_0-rmse:0.08217
# [2033]	validation_0-rmse:0.08217
# [2034]	validation_0-rmse:0.08217
# [2035]	validation_0-rmse:0.08217
# [2036]	validation_0-rmse:0.08217
# Train_RMSE: 0.010551030363524491
# Valid_RMSE: 0.0821605948613366

# %%
'''
# !pip uninstall -y numpy
# !pip install numpy==1.26.4 --no-cache-dir
# !pip install catboost --no-cache-dir --no-deps

import numpy as np
print(np.__version__)
'''
# Out:
# '\n!pip uninstall -y numpy\n!pip install numpy==1.26.4 --no-cache-dir\n!pip install catboost --no-cache-dir --no-deps\n\nimport numpy as np\nprint(np.__version__)\n'

# %%
'''
import catboost

print(np.__version__)  # numpyのバージョン確認
print(catboost.__version__)  # catboostのバージョン確認
'''
# Out:
# '\nimport catboost\n\nprint(np.__version__)  # numpyのバージョン確認\nprint(catboost.__version__)  # catboostのバージョン確認\n'

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (6.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.2)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (1.32.0)

# %%
# catboost
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

params = {'random_state': 42,
          'iterations': 10000,
          'learning_rate': 0.01,
          'eval_metric': 'RMSE',
          'early_stopping_rounds': 50}
cat_model = CatBoostRegressor(**params)
cat_model.fit(X_train, y_train, eval_set=(X_valid, y_valid))
cat_train_pred = cat_model.predict(X_train)
cat_valid_pred = cat_model.predict(X_valid)
cat_test_pred = cat_model.predict(X_test)

print(f'Train_RMSE: {np.sqrt(mean_squared_error(y_train, cat_train_pred))}')
print(f'Valid_RMSE: {np.sqrt(mean_squared_error(y_valid, cat_valid_pred))}')

plt.figure(figsize=(12, 6))

sns.lineplot(x=X_train.index, y=y_train, label='Train Actual')
sns.lineplot(x=X_valid.index, y=y_valid, label='Valid Actual')
sns.lineplot(x=X_train.index, y=cat_train_pred, label='Train Predicted')
sns.lineplot(x=X_valid.index, y=cat_valid_pred, label='Valid Predicted')

plt.grid()
plt.legend()
plt.show()
# Out:
# 0:	learn: 0.2161206	test: 0.2355681	best: 0.2355681 (0)	total: 126ms	remaining: 21m 3s
# 1:	learn: 0.2144191	test: 0.2339539	best: 0.2339539 (1)	total: 200ms	remaining: 16m 40s
# 2:	learn: 0.2127366	test: 0.2323676	best: 0.2323676 (2)	total: 304ms	remaining: 16m 52s
# 3:	learn: 0.2111205	test: 0.2308937	best: 0.2308937 (3)	total: 414ms	remaining: 17m 15s
# 4:	learn: 0.2095067	test: 0.2293311	best: 0.2293311 (4)	total: 536ms	remaining: 17m 50s
# 5:	learn: 0.2079707	test: 0.2278969	best: 0.2278969 (5)	total: 658ms	remaining: 18m 15s
# 6:	learn: 0.2063815	test: 0.2263518	best: 0.2263518 (6)	total: 817ms	remaining: 19m 25s
# 7:	learn: 0.2047687	test: 0.2248362	best: 0.2248362 (7)	total: 954ms	remaining: 19m 51s
# 8:	learn: 0.2032378	test: 0.2234081	best: 0.2234081 (8)	total: 1.1s	remaining: 20m 17s
# 119:	learn: 0.0990738	test: 0.1280886	best: 0.1280886 (119)	total: 14.3s	remaining: 19m 33s
# 120:	learn: 0.0986065	test: 0.1276505	best: 0.1276505 (120)	total: 14.3s	remaining: 19m 31s
# 121:	learn: 0.0981593	test: 0.1272377	best: 0.1272377 (121)	total: 14.4s	remaining: 19m 29s
# 122:	learn: 0.0977113	test: 0.1268484	best: 0.1268484 (122)	total: 14.5s	remaining: 19m 27s
# 123:	learn: 0.0971799	test: 0.1263623	best: 0.1263623 (123)	total: 14.6s	remaining: 19m 25s
# 124:	learn: 0.0967077	test: 0.1259555	best: 0.1259555 (124)	total: 14.7s	remaining: 19m 23s
# 125:	learn: 0.0962263	test: 0.1255275	best: 0.1255275 (125)	total: 14.8s	remaining: 19m 21s
# 126:	learn: 0.0957806	test: 0.1251384	best: 0.1251384 (126)	total: 14.9s	remaining: 19m 20s
# 127:	learn: 0.0953378	test: 0.1247667	best: 0.1247667 (127)	total: 15s	remaining: 19m 17s
# 128:	learn: 0.0949000	test: 0.1243433	best: 0.1243433 (128)	total: 15.2s	remaining: 19m 21s
# 129:	learn: 0.0944123	test: 0.1239429	best: 0.1239429 (129)	total: 15.3s	remaining: 19m 24s
# 130:	learn: 0.0939936	test: 0.1235461	best: 0.1235461 (130)	total: 15.5s	remaining: 19m 30s
# 131:	learn: 0.0934980	test: 0.1231458	best: 0.1231458 (131)	total: 15.7s	remaining: 19m 35s
# 132:	learn: 0.0930020	test: 0.1227321	best: 0.1227321 (132)	total: 15.9s	remaining: 19m 40s
# 133:	learn: 0.0925342	test: 0.1223647	best: 0.1223647 (133)	total: 16.1s	remaining: 19m 44s
# 134:	learn: 0.0920709	test: 0.1220066	best: 0.1220066 (134)	total: 16.3s	remaining: 19m 50s
# 135:	learn: 0.0916134	test: 0.1216588	best: 0.1216588 (135)	total: 16.4s	remaining: 19m 52s
# 136:	learn: 0.0911991	test: 0.1212943	best: 0.1212943 (136)	total: 16.6s	remaining: 19m 56s
# 137:	learn: 0.0907417	test: 0.1209212	best: 0.1209212 (137)	total: 16.7s	remaining: 19m 56s
# 138:	learn: 0.0902769	test: 0.1205491	best: 0.1205491 (138)	total: 16.9s	remaining: 19m 56s
# 139:	learn: 0.0898465	test: 0.1201993	best: 0.1201993 (139)	total: 17s	remaining: 20m
# 140:	learn: 0.0893987	test: 0.1198400	best: 0.1198400 (140)	total: 17.2s	remaining: 20m 1s
# 141:	learn: 0.0889632	test: 0.1194755	best: 0.1194755 (141)	total: 17.4s	remaining: 20m 5s
# 142:	learn: 0.0885990	test: 0.1191675	best: 0.1191675 (142)	total: 17.5s	remaining: 20m 7s
# 143:	learn: 0.0882318	test: 0.1188225	best: 0.1188225 (143)	total: 17.7s	remaining: 20m 9s
# 144:	learn: 0.0878517	test: 0.1184995	best: 0.1184995 (144)	total: 17.8s	remaining: 20m 10s
# 145:	learn: 0.0874625	test: 0.1181590	best: 0.1181590 (145)	total: 18s	remaining: 20m 13s
# 146:	learn: 0.0870618	test: 0.1177986	best: 0.1177986 (146)	total: 18.2s	remaining: 20m 22s
# 147:	learn: 0.0866627	test: 0.1174508	best: 0.1174508 (147)	total: 18.4s	remaining: 20m 25s
# 148:	learn: 0.0862501	test: 0.1171074	best: 0.1171074 (148)	total: 18.5s	remaining: 20m 24s
# 149:	learn: 0.0858604	test: 0.1167511	best: 0.1167511 (149)	total: 18.6s	remaining: 20m 22s
# 150:	learn: 0.0854973	test: 0.1164154	best: 0.1164154 (150)	total: 18.7s	remaining: 20m 22s
# 151:	learn: 0.0851254	test: 0.1161180	best: 0.1161180 (151)	total: 18.9s	remaining: 20m 23s
# 152:	learn: 0.0848111	test: 0.1158198	best: 0.1158198 (152)	total: 19.1s	remaining: 20m 26s
# 153:	learn: 0.0844444	test: 0.1155111	best: 0.1155111 (153)	total: 19.2s	remaining: 20m 25s
# 154:	learn: 0.0840492	test: 0.1152079	best: 0.1152079 (154)	total: 19.4s	remaining: 20m 30s
# 155:	learn: 0.0836881	test: 0.1149523	best: 0.1149523 (155)	total: 19.5s	remaining: 20m 31s
# 156:	learn: 0.0833270	test: 0.1146958	best: 0.1146958 (156)	total: 19.6s	remaining: 20m 29s
# 157:	learn: 0.0829776	test: 0.1143883	best: 0.1143883 (157)	total: 19.7s	remaining: 20m 29s
# 158:	learn: 0.0826322	test: 0.1140931	best: 0.1140931 (158)	total: 19.9s	remaining: 20m 31s
# 159:	learn: 0.0822633	test: 0.1137803	best: 0.1137803 (159)	total: 20s	remaining: 20m 31s
# 160:	learn: 0.0819364	test: 0.1134822	best: 0.1134822 (160)	total: 20.1s	remaining: 20m 27s
# 161:	learn: 0.0815982	test: 0.1132032	best: 0.1132032 (161)	total: 20.2s	remaining: 20m 25s
# 162:	learn: 0.0812918	test: 0.1129958	best: 0.1129958 (162)	total: 20.3s	remaining: 20m 24s
# 163:	learn: 0.0810019	test: 0.1127474	best: 0.1127474 (163)	total: 20.4s	remaining: 20m 25s
# 164:	learn: 0.0807016	test: 0.1125127	best: 0.1125127 (164)	total: 20.6s	remaining: 20m 26s
# 165:	learn: 0.0803428	test: 0.1122774	best: 0.1122774 (165)	total: 20.7s	remaining: 20m 24s
# 166:	learn: 0.0799810	test: 0.1119778	best: 0.1119778 (166)	total: 20.8s	remaining: 20m 22s
# 167:	learn: 0.0796481	test: 0.1116976	best: 0.1116976 (167)	total: 20.8s	remaining: 20m 19s
# 168:	learn: 0.0793746	test: 0.1114695	best: 0.1114695 (168)	total: 20.9s	remaining: 20m 18s
# 169:	learn: 0.0790702	test: 0.1112320	best: 0.1112320 (169)	total: 21.1s	remaining: 20m 18s
# 170:	learn: 0.0788049	test: 0.1110065	best: 0.1110065 (170)	total: 21.3s	remaining: 20m 23s
# 171:	learn: 0.0784941	test: 0.1107425	best: 0.1107425 (171)	total: 21.4s	remaining: 20m 20s
# 172:	learn: 0.0781657	test: 0.1104708	best: 0.1104708 (172)	total: 21.4s	remaining: 20m 18s
# 173:	learn: 0.0778800	test: 0.1102133	best: 0.1102133 (173)	total: 21.5s	remaining: 20m 16s
# 174:	learn: 0.0775599	test: 0.1100041	best: 0.1100041 (174)	total: 21.6s	remaining: 20m 15s
# 258:	learn: 0.0603662	test: 0.0976522	best: 0.0976522 (258)	total: 31.6s	remaining: 19m 48s
# 259:	learn: 0.0601880	test: 0.0975636	best: 0.0975636 (259)	total: 31.7s	remaining: 19m 47s
# 260:	learn: 0.0600655	test: 0.0974604	best: 0.0974604 (260)	total: 31.8s	remaining: 19m 46s
# 261:	learn: 0.0599400	test: 0.0973653	best: 0.0973653 (261)	total: 32s	remaining: 19m 48s
# 262:	learn: 0.0598120	test: 0.0972858	best: 0.0972858 (262)	total: 32.2s	remaining: 19m 50s
# 263:	learn: 0.0596807	test: 0.0972196	best: 0.0972196 (263)	total: 32.4s	remaining: 19m 53s
# 264:	learn: 0.0595580	test: 0.0971301	best: 0.0971301 (264)	total: 32.5s	remaining: 19m 55s
# 265:	learn: 0.0594046	test: 0.0970157	best: 0.0970157 (265)	total: 32.7s	remaining: 19m 57s
# 266:	learn: 0.0592610	test: 0.0969415	best: 0.0969415 (266)	total: 32.9s	remaining: 20m
# 267:	learn: 0.0591361	test: 0.0968745	best: 0.0968745 (267)	total: 33.1s	remaining: 20m 2s
# 268:	learn: 0.0589781	test: 0.0968013	best: 0.0968013 (268)	total: 33.3s	remaining: 20m 4s
# 269:	learn: 0.0588480	test: 0.0967027	best: 0.0967027 (269)	total: 33.5s	remaining: 20m 5s
# 270:	learn: 0.0587130	test: 0.0966392	best: 0.0966392 (270)	total: 33.6s	remaining: 20m 5s
# 271:	learn: 0.0585760	test: 0.0965328	best: 0.0965328 (271)	total: 33.7s	remaining: 20m 4s
# 272:	learn: 0.0584326	test: 0.0964542	best: 0.0964542 (272)	total: 33.8s	remaining: 20m 4s
# 273:	learn: 0.0583281	test: 0.0963842	best: 0.0963842 (273)	total: 33.9s	remaining: 20m 4s
# 274:	learn: 0.0582336	test: 0.0962920	best: 0.0962920 (274)	total: 34s	remaining: 20m 3s
# 275:	learn: 0.0581322	test: 0.0962187	best: 0.0962187 (275)	total: 34.1s	remaining: 20m 2s
# 276:	learn: 0.0579838	test: 0.0961229	best: 0.0961229 (276)	total: 34.2s	remaining: 20m 1s
# 277:	learn: 0.0578646	test: 0.0960592	best: 0.0960592 (277)	total: 34.3s	remaining: 20m
# 278:	learn: 0.0577544	test: 0.0959785	best: 0.0959785 (278)	total: 34.5s	remaining: 20m
# 279:	learn: 0.0576112	test: 0.0959336	best: 0.0959336 (279)	total: 34.6s	remaining: 20m 1s
# 280:	learn: 0.0575147	test: 0.0958735	best: 0.0958735 (280)	total: 34.7s	remaining: 20m
# 281:	learn: 0.0573893	test: 0.0957872	best: 0.0957872 (281)	total: 34.9s	remaining: 20m 1s
# 282:	learn: 0.0572856	test: 0.0957433	best: 0.0957433 (282)	total: 35s	remaining: 20m
# 283:	learn: 0.0571940	test: 0.0956828	best: 0.0956828 (283)	total: 35.1s	remaining: 19m 59s
# 284:	learn: 0.0570838	test: 0.0955820	best: 0.0955820 (284)	total: 35.2s	remaining: 19m 59s
# 285:	learn: 0.0569741	test: 0.0954953	best: 0.0954953 (285)	total: 35.3s	remaining: 19m 58s
# 369:	learn: 0.0493554	test: 0.0909455	best: 0.0909455 (369)	total: 40.5s	remaining: 17m 34s
# 370:	learn: 0.0492873	test: 0.0909023	best: 0.0909023 (370)	total: 40.6s	remaining: 17m 32s
# 371:	learn: 0.0492232	test: 0.0908741	best: 0.0908741 (371)	total: 40.6s	remaining: 17m 31s
# 372:	learn: 0.0491454	test: 0.0908164	best: 0.0908164 (372)	total: 40.7s	remaining: 17m 29s
# 373:	learn: 0.0490700	test: 0.0907369	best: 0.0907369 (373)	total: 40.7s	remaining: 17m 27s
# 374:	learn: 0.0490118	test: 0.0907197	best: 0.0907197 (374)	total: 40.8s	remaining: 17m 26s
# 375:	learn: 0.0489151	test: 0.0906778	best: 0.0906778 (375)	total: 40.8s	remaining: 17m 24s
# 376:	learn: 0.0488570	test: 0.0906260	best: 0.0906260 (376)	total: 40.8s	remaining: 17m 22s
# 377:	learn: 0.0488017	test: 0.0906205	best: 0.0906205 (377)	total: 40.9s	remaining: 17m 21s
# 378:	learn: 0.0487476	test: 0.0905679	best: 0.0905679 (378)	total: 40.9s	remaining: 17m 19s
# 379:	learn: 0.0486888	test: 0.0905355	best: 0.0905355 (379)	total: 41s	remaining: 17m 17s
# 380:	learn: 0.0486392	test: 0.0905190	best: 0.0905190 (380)	total: 41s	remaining: 17m 15s
# 381:	learn: 0.0485765	test: 0.0905010	best: 0.0905010 (381)	total: 41.1s	remaining: 17m 14s
# 382:	learn: 0.0485215	test: 0.0904638	best: 0.0904638 (382)	total: 41.1s	remaining: 17m 12s
# 383:	learn: 0.0484354	test: 0.0904273	best: 0.0904273 (383)	total: 41.2s	remaining: 17m 10s
# 384:	learn: 0.0483468	test: 0.0903910	best: 0.0903910 (384)	total: 41.2s	remaining: 17m 9s
# 385:	learn: 0.0483052	test: 0.0903598	best: 0.0903598 (385)	total: 41.3s	remaining: 17m 7s
# 386:	learn: 0.0482377	test: 0.0903143	best: 0.0903143 (386)	total: 41.3s	remaining: 17m 5s
# 387:	learn: 0.0481709	test: 0.0902806	best: 0.0902806 (387)	total: 41.3s	remaining: 17m 4s
# 388:	learn: 0.0481138	test: 0.0902481	best: 0.0902481 (388)	total: 41.4s	remaining: 17m 2s
# 389:	learn: 0.0480485	test: 0.0902094	best: 0.0902094 (389)	total: 41.4s	remaining: 17m 1s
# 390:	learn: 0.0479974	test: 0.0901655	best: 0.0901655 (390)	total: 41.5s	remaining: 16m 59s
# 391:	learn: 0.0479270	test: 0.0900961	best: 0.0900961 (391)	total: 41.5s	remaining: 16m 57s
# 392:	learn: 0.0478685	test: 0.0900411	best: 0.0900411 (392)	total: 41.6s	remaining: 16m 56s
# 393:	learn: 0.0478252	test: 0.0900208	best: 0.0900208 (393)	total: 41.6s	remaining: 16m 54s
# 394:	learn: 0.0477395	test: 0.0899814	best: 0.0899814 (394)	total: 41.7s	remaining: 16m 53s
# 395:	learn: 0.0476531	test: 0.0899298	best: 0.0899298 (395)	total: 41.7s	remaining: 16m 51s
# 396:	learn: 0.0475729	test: 0.0898720	best: 0.0898720 (396)	total: 41.8s	remaining: 16m 50s
# 397:	learn: 0.0474937	test: 0.0898145	best: 0.0898145 (397)	total: 41.8s	remaining: 16m 48s
# 398:	learn: 0.0474333	test: 0.0897574	best: 0.0897574 (398)	total: 41.9s	remaining: 16m 47s
# 399:	learn: 0.0473833	test: 0.0897453	best: 0.0897453 (399)	total: 41.9s	remaining: 16m 45s
# 400:	learn: 0.0473343	test: 0.0897314	best: 0.0897314 (400)	total: 42s	remaining: 16m 44s
# 401:	learn: 0.0472652	test: 0.0896774	best: 0.0896774 (401)	total: 42s	remaining: 16m 42s
# 402:	learn: 0.0472081	test: 0.0896490	best: 0.0896490 (402)	total: 42s	remaining: 16m 41s
# 403:	learn: 0.0471127	test: 0.0895960	best: 0.0895960 (403)	total: 42.1s	remaining: 16m 39s
# 404:	learn: 0.0470624	test: 0.0895319	best: 0.0895319 (404)	total: 42.1s	remaining: 16m 38s
# 405:	learn: 0.0470146	test: 0.0895031	best: 0.0895031 (405)	total: 42.2s	remaining: 16m 36s
# 406:	learn: 0.0469369	test: 0.0894714	best: 0.0894714 (406)	total: 42.2s	remaining: 16m 35s
# 407:	learn: 0.0468949	test: 0.0894224	best: 0.0894224 (407)	total: 42.3s	remaining: 16m 33s
# 408:	learn: 0.0468357	test: 0.0894264	best: 0.0894224 (407)	total: 42.3s	remaining: 16m 32s
# 409:	learn: 0.0467755	test: 0.0893794	best: 0.0893794 (409)	total: 42.4s	remaining: 16m 30s
# 410:	learn: 0.0467328	test: 0.0893403	best: 0.0893403 (410)	total: 42.4s	remaining: 16m 29s
# 411:	learn: 0.0466713	test: 0.0892955	best: 0.0892955 (411)	total: 42.4s	remaining: 16m 27s
# 412:	learn: 0.0466191	test: 0.0892693	best: 0.0892693 (412)	total: 42.5s	remaining: 16m 26s
# 413:	learn: 0.0465776	test: 0.0892464	best: 0.0892464 (413)	total: 42.5s	remaining: 16m 24s
# 414:	learn: 0.0465260	test: 0.0892271	best: 0.0892271 (414)	total: 42.6s	remaining: 16m 23s
# 415:	learn: 0.0464468	test: 0.0891966	best: 0.0891966 (415)	total: 42.6s	remaining: 16m 22s
# 416:	learn: 0.0463770	test: 0.0891594	best: 0.0891594 (416)	total: 42.7s	remaining: 16m 20s
# 417:	learn: 0.0463243	test: 0.0891117	best: 0.0891117 (417)	total: 42.7s	remaining: 16m 19s
# 418:	learn: 0.0462651	test: 0.0890628	best: 0.0890628 (418)	total: 42.8s	remaining: 16m 18s
# 419:	learn: 0.0462137	test: 0.0890350	best: 0.0890350 (419)	total: 42.8s	remaining: 16m 16s
# 420:	learn: 0.0461682	test: 0.0889975	best: 0.0889975 (420)	total: 42.9s	remaining: 16m 15s
# 421:	learn: 0.0461192	test: 0.0889687	best: 0.0889687 (421)	total: 42.9s	remaining: 16m 14s
# 422:	learn: 0.0460538	test: 0.0889273	best: 0.0889273 (422)	total: 43s	remaining: 16m 12s
# 423:	learn: 0.0460073	test: 0.0889001	best: 0.0889001 (423)	total: 43s	remaining: 16m 11s
# 424:	learn: 0.0459525	test: 0.0888726	best: 0.0888726 (424)	total: 43.1s	remaining: 16m 10s
# 425:	learn: 0.0459161	test: 0.0888603	best: 0.0888603 (425)	total: 43.1s	remaining: 16m 8s
# 426:	learn: 0.0458290	test: 0.0888219	best: 0.0888219 (426)	total: 43.1s	remaining: 16m 7s
# 427:	learn: 0.0457534	test: 0.0887930	best: 0.0887930 (427)	total: 43.2s	remaining: 16m 5s
# 428:	learn: 0.0456916	test: 0.0887594	best: 0.0887594 (428)	total: 43.2s	remaining: 16m 4s
# 429:	learn: 0.0456465	test: 0.0887098	best: 0.0887098 (429)	total: 43.3s	remaining: 16m 3s
# 430:	learn: 0.0455857	test: 0.0886929	best: 0.0886929 (430)	total: 43.3s	remaining: 16m 1s
# 431:	learn: 0.0455293	test: 0.0886442	best: 0.0886442 (431)	total: 43.4s	remaining: 16m
# 432:	learn: 0.0454874	test: 0.0886235	best: 0.0886235 (432)	total: 43.4s	remaining: 15m 59s
# 433:	learn: 0.0454527	test: 0.0886221	best: 0.0886221 (433)	total: 43.5s	remaining: 15m 57s
# 434:	learn: 0.0453969	test: 0.0885836	best: 0.0885836 (434)	total: 43.5s	remaining: 15m 56s
# 435:	learn: 0.0453405	test: 0.0885092	best: 0.0885092 (435)	total: 43.5s	remaining: 15m 55s
# 436:	learn: 0.0452896	test: 0.0884788	best: 0.0884788 (436)	total: 43.6s	remaining: 15m 53s
# 437:	learn: 0.0452455	test: 0.0884496	best: 0.0884496 (437)	total: 43.6s	remaining: 15m 52s
# 438:	learn: 0.0451969	test: 0.0883918	best: 0.0883918 (438)	total: 43.7s	remaining: 15m 51s
# 439:	learn: 0.0451498	test: 0.0883853	best: 0.0883853 (439)	total: 43.7s	remaining: 15m 50s
# 440:	learn: 0.0450807	test: 0.0883514	best: 0.0883514 (440)	total: 43.8s	remaining: 15m 49s
# 441:	learn: 0.0450114	test: 0.0883145	best: 0.0883145 (441)	total: 43.8s	remaining: 15m 47s
# 442:	learn: 0.0449546	test: 0.0882760	best: 0.0882760 (442)	total: 43.9s	remaining: 15m 46s
# 443:	learn: 0.0448982	test: 0.0882438	best: 0.0882438 (443)	total: 43.9s	remaining: 15m 45s
# 444:	learn: 0.0448449	test: 0.0882106	best: 0.0882106 (444)	total: 44s	remaining: 15m 44s
# 445:	learn: 0.0448111	test: 0.0881998	best: 0.0881998 (445)	total: 44.1s	remaining: 15m 44s
# 446:	learn: 0.0447580	test: 0.0881647	best: 0.0881647 (446)	total: 44.2s	remaining: 15m 43s
# 447:	learn: 0.0447229	test: 0.0881443	best: 0.0881443 (447)	total: 44.2s	remaining: 15m 43s
# 448:	learn: 0.0446850	test: 0.0881295	best: 0.0881295 (448)	total: 44.3s	remaining: 15m 42s
# 449:	learn: 0.0446259	test: 0.0881047	best: 0.0881047 (449)	total: 44.4s	remaining: 15m 42s
# 450:	learn: 0.0445837	test: 0.0880925	best: 0.0880925 (450)	total: 44.5s	remaining: 15m 41s
# 451:	learn: 0.0445444	test: 0.0880425	best: 0.0880425 (451)	total: 44.6s	remaining: 15m 41s
# 452:	learn: 0.0445158	test: 0.0880291	best: 0.0880291 (452)	total: 44.7s	remaining: 15m 41s
# 453:	learn: 0.0444641	test: 0.0879930	best: 0.0879930 (453)	total: 44.8s	remaining: 15m 41s
# 454:	learn: 0.0444231	test: 0.0879498	best: 0.0879498 (454)	total: 44.8s	remaining: 15m 40s
# 455:	learn: 0.0443545	test: 0.0879249	best: 0.0879249 (455)	total: 44.9s	remaining: 15m 40s
# 456:	learn: 0.0443192	test: 0.0879183	best: 0.0879183 (456)	total: 45s	remaining: 15m 39s
# 457:	learn: 0.0442700	test: 0.0878791	best: 0.0878791 (457)	total: 45.1s	remaining: 15m 39s
# 458:	learn: 0.0442365	test: 0.0878640	best: 0.0878640 (458)	total: 45.2s	remaining: 15m 39s
# 459:	learn: 0.0441804	test: 0.0878520	best: 0.0878520 (459)	total: 45.3s	remaining: 15m 38s
# 460:	learn: 0.0441451	test: 0.0878420	best: 0.0878420 (460)	total: 45.4s	remaining: 15m 38s
# 461:	learn: 0.0440768	test: 0.0878150	best: 0.0878150 (461)	total: 45.4s	remaining: 15m 38s
# 462:	learn: 0.0440316	test: 0.0878035	best: 0.0878035 (462)	total: 45.5s	remaining: 15m 37s
# 463:	learn: 0.0439940	test: 0.0877891	best: 0.0877891 (463)	total: 45.6s	remaining: 15m 37s
# 464:	learn: 0.0439532	test: 0.0877470	best: 0.0877470 (464)	total: 45.7s	remaining: 15m 36s
# 465:	learn: 0.0439198	test: 0.0877175	best: 0.0877175 (465)	total: 45.8s	remaining: 15m 36s
# 466:	learn: 0.0438842	test: 0.0876852	best: 0.0876852 (466)	total: 45.9s	remaining: 15m 36s
# 467:	learn: 0.0438250	test: 0.0876685	best: 0.0876685 (467)	total: 46s	remaining: 15m 36s
# 468:	learn: 0.0437895	test: 0.0876414	best: 0.0876414 (468)	total: 46s	remaining: 15m 35s
# 469:	learn: 0.0437547	test: 0.0876258	best: 0.0876258 (469)	total: 46.1s	remaining: 15m 35s
# 470:	learn: 0.0437205	test: 0.0876129	best: 0.0876129 (470)	total: 46.2s	remaining: 15m 34s
# 471:	learn: 0.0436403	test: 0.0875832	best: 0.0875832 (471)	total: 46.3s	remaining: 15m 34s
# 472:	learn: 0.0435953	test: 0.0875470	best: 0.0875470 (472)	total: 46.4s	remaining: 15m 34s
# 473:	learn: 0.0435623	test: 0.0875131	best: 0.0875131 (473)	total: 46.5s	remaining: 15m 33s
# 474:	learn: 0.0435278	test: 0.0875026	best: 0.0875026 (474)	total: 46.5s	remaining: 15m 33s
# 475:	learn: 0.0434956	test: 0.0874558	best: 0.0874558 (475)	total: 46.6s	remaining: 15m 32s
# 476:	learn: 0.0434457	test: 0.0874086	best: 0.0874086 (476)	total: 46.7s	remaining: 15m 32s
# 477:	learn: 0.0434099	test: 0.0873886	best: 0.0873886 (477)	total: 46.8s	remaining: 15m 32s
# 478:	learn: 0.0433715	test: 0.0873498	best: 0.0873498 (478)	total: 46.9s	remaining: 15m 32s
# 479:	learn: 0.0433171	test: 0.0873275	best: 0.0873275 (479)	total: 47s	remaining: 15m 31s
# 480:	learn: 0.0432856	test: 0.0873169	best: 0.0873169 (480)	total: 47.1s	remaining: 15m 31s
# 481:	learn: 0.0432524	test: 0.0872794	best: 0.0872794 (481)	total: 47.2s	remaining: 15m 31s
# 482:	learn: 0.0432180	test: 0.0872658	best: 0.0872658 (482)	total: 47.3s	remaining: 15m 31s
# 483:	learn: 0.0431668	test: 0.0872424	best: 0.0872424 (483)	total: 47.3s	remaining: 15m 30s
# 484:	learn: 0.0431279	test: 0.0872088	best: 0.0872088 (484)	total: 47.4s	remaining: 15m 30s
# 485:	learn: 0.0430559	test: 0.0871761	best: 0.0871761 (485)	total: 47.5s	remaining: 15m 30s
# 486:	learn: 0.0430193	test: 0.0871312	best: 0.0871312 (486)	total: 47.6s	remaining: 15m 29s
# 487:	learn: 0.0429762	test: 0.0871136	best: 0.0871136 (487)	total: 47.7s	remaining: 15m 29s
# 488:	learn: 0.0429138	test: 0.0870989	best: 0.0870989 (488)	total: 47.8s	remaining: 15m 28s
# 489:	learn: 0.0428818	test: 0.0870867	best: 0.0870867 (489)	total: 47.8s	remaining: 15m 28s
# 490:	learn: 0.0428030	test: 0.0870570	best: 0.0870570 (490)	total: 47.9s	remaining: 15m 26s
# 491:	learn: 0.0427565	test: 0.0870273	best: 0.0870273 (491)	total: 47.9s	remaining: 15m 26s
# 492:	learn: 0.0427206	test: 0.0869915	best: 0.0869915 (492)	total: 48s	remaining: 15m 25s
# 493:	learn: 0.0426763	test: 0.0869425	best: 0.0869425 (493)	total: 48s	remaining: 15m 23s
# 494:	learn: 0.0426393	test: 0.0869283	best: 0.0869283 (494)	total: 48.1s	remaining: 15m 22s
# 495:	learn: 0.0425961	test: 0.0869108	best: 0.0869108 (495)	total: 48.1s	remaining: 15m 21s
# 496:	learn: 0.0425723	test: 0.0869051	best: 0.0869051 (496)	total: 48.1s	remaining: 15m 20s
# 497:	learn: 0.0425424	test: 0.0868754	best: 0.0868754 (497)	total: 48.2s	remaining: 15m 19s
# 498:	learn: 0.0425106	test: 0.0868568	best: 0.0868568 (498)	total: 48.2s	remaining: 15m 18s
# 499:	learn: 0.0424674	test: 0.0868382	best: 0.0868382 (499)	total: 48.3s	remaining: 15m 17s
# 500:	learn: 0.0424008	test: 0.0868178	best: 0.0868178 (500)	total: 48.3s	remaining: 15m 16s
# 501:	learn: 0.0423676	test: 0.0868008	best: 0.0868008 (501)	total: 48.4s	remaining: 15m 15s
# 502:	learn: 0.0423307	test: 0.0867812	best: 0.0867812 (502)	total: 48.4s	remaining: 15m 14s
# 503:	learn: 0.0422878	test: 0.0867731	best: 0.0867731 (503)	total: 48.5s	remaining: 15m 12s
# 504:	learn: 0.0422439	test: 0.0867579	best: 0.0867579 (504)	total: 48.5s	remaining: 15m 11s
# 505:	learn: 0.0422084	test: 0.0867362	best: 0.0867362 (505)	total: 48.5s	remaining: 15m 10s
# 506:	learn: 0.0421798	test: 0.0867223	best: 0.0867223 (506)	total: 48.6s	remaining: 15m 9s
best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 11s
# 1675:	learn: 0.0226691	test: 0.0817013	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 11s
# 1676:	learn: 0.0226636	test: 0.0817030	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 11s
# 1677:	learn: 0.0226571	test: 0.0817026	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 10s
# 1678:	learn: 0.0226484	test: 0.0817014	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 10s
# 1679:	learn: 0.0226408	test: 0.0816958	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 10s
# 1680:	learn: 0.0226311	test: 0.0816980	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 10s
# 1681:	learn: 0.0226234	test: 0.0816945	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 10s
# 1682:	learn: 0.0226122	test: 0.0816915	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 9s
# 1683:	learn: 0.0226076	test: 0.0816826	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 9s
# 1684:	learn: 0.0226002	test: 0.0816792	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 9s
# 1685:	learn: 0.0225892	test: 0.0816780	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 9s
# 1686:	learn: 0.0225804	test: 0.0816830	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 8s
# 1687:	learn: 0.0225728	test: 0.0816826	best: 0.0816482 (1637)	total: 2m 3s	remaining: 10m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.08164821655
# bestIteration = 1637
#
# Shrink model to first 1638 iterations.
# Train_RMSE: 0.02296763379723843
# Valid_RMSE: 0.08164821566615654

# %%
'''
# MLP
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

params = {'hidden_layer_sizes': (1024, 512, 256, 128, 64, 32),
          'activation': 'tanh',
          'solver': 'adam',
          'random_state': 42
}
mlp_model = MLPRegressor(**params)
mlp_model.fit(X_train_scaled, y_train_scaled)
mlp_train_pred = y_scaler.inverse_transform(mlp_model.predict(X_train_scaled).reshape(-1, 1))
mlp_valid_pred = y_scaler.inverse_transform(mlp_model.predict(X_valid_scaled).reshape(-1, 1))
mlp_test_pred = y_scaler.inverse_transform(mlp_model.predict(X_test_scaled).reshape(-1, 1))

print(f'Train_RMSE: {np.sqrt(mean_squared_error(y_train_scaled, mlp_train_pred))}')
print(f'Valid_RMSE: {np.sqrt(mean_squared_error(y_valid_scaled, mlp_valid_pred))}')

plt.figure(figsize=(12, 6))

sns.lineplot(x=X_train.index, y=y_train, label='Train Actual')
sns.lineplot(x=X_valid.index, y=y_valid, label='Valid Actual')
sns.lineplot(x=X_train.index, y=mlp_train_pred.flatten(), label='Train Predicted')
sns.lineplot(x=X_valid.index, y=mlp_valid_pred.flatten(), label='Valid Predicted')

plt.grid()
plt.legend()
plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-8504b237dbfc> in <cell line: 0>()
#      11 mlp_model.fit(X_train_scaled, y_train_scaled)
#      12 mlp_train_pred = y_scaler.inverse_transform(mlp_model.predict(X_train_scaled).reshape(-1, 1))
# ---> 13 mlp_valid_pred = y_scaler.inverse_transform(mlp_model.predict(X_valid_scaled).reshape(-1, 1))
#      14 mlp_test_pred = y_scaler.inverse_transform(mlp_model.predict(X_test_scaled).reshape(-1, 1))
#      15
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in predict(self, X)
#    1624         """
#    1625         check_is_fitted(self)
# -> 1626         return self._predict(X)
#    1627
#    1628     def _predict(self, X, check_input=True):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in _predict(self, X, check_input)
#    1628     def _predict(self, X, check_input=True):
#    1629         """Private predict method with optional input validation"""
# -> 1630         y_pred = self._forward_pass_fast(X, check_input=check_input)
#    1631         if y_pred.shape[1] == 1:
#    1632             return y_pred.ravel()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in _forward_pass_fast(self, X, check_input)
#     210         hidden_activation = ACTIVATIONS[self.activation]
#     211         for i in range(self.n_layers_ - 1):
# --> 212             activation = safe_sparse_dot(activation, self.coefs_[i])
#     213             activation += self.intercepts_[i]
#     214             if i != self.n_layers_ - 2:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     204
#     205     if (
# --> 206         sparse.issparse(a)
#     207         and sparse.issparse(b)
#     208         and dense_output
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_base.py in issparse(x)
#    1399
#    1400
# -> 1401 def issparse(x):
#    1402     """Is `x` of a sparse array or sparse matrix type?
#    1403
#
# KeyboardInterrupt:

# %%
# アンサンブル
ensemble_list = ['lgbm', 'xgb', 'cat']
ensemble_train_pred = (lgbm_train_pred + xgb_train_pred + cat_train_pred) / len(ensemble_list)
ensemble_valid_pred = (lgbm_valid_pred + xgb_valid_pred + cat_valid_pred) / len(ensemble_list)
ensemble_test_pred = (lgbm_test_pred + xgb_test_pred + cat_test_pred) / len(ensemble_list)

print(f'Train_RMSE: {np.sqrt(mean_squared_error(y_train, ensemble_train_pred))}')
print(f'Valid_RMSE: {np.sqrt(mean_squared_error(y_valid, ensemble_valid_pred))}')
# Out:
# Train_RMSE: 0.014364729824174877
# Valid_RMSE: 0.0813291584791467

# %%
# 特徴量重要度
plt.figure(figsize=(10, 40))
feature_importance = pd.DataFrame(lgbm_model.feature_importances_, index=X_train.columns, columns=['importance'])
feature_importance.sort_values('importance', ascending=False)
plt.barh(feature_importance.index, feature_importance['importance'])
plt.show()

# %% [markdown]
# # .

# %%
submission = pd.read_csv('/content/drive/MyDrive/Kaggle/Prediction_of_E-commerce_Users/submission.csv')
submission
# Out:
#                  datetime  e_users
# 0     2024-09-01 00:00:00        0
# 1     2024-09-01 01:00:00        0
# 2     2024-09-01 02:00:00        0
# 3     2024-09-01 03:00:00        0
# 4     2024-09-01 04:00:00        0
# ...                   ...      ...
# 2923  2024-12-31 19:00:00        0
# 2924  2024-12-31 20:00:00        0
# 2925  2024-12-31 21:00:00        0
# 2926  2024-12-31 22:00:00        0
# 2927  2024-12-31 23:00:00        0
#
# [2928 rows x 2 columns]

# %%
ensemble_test_pred
# Out:
# array([10.70034884, 10.59675153, 10.56528719, ..., 11.13869987,
#        11.12930366, 11.15253411])

# %%
pred_log_value = ensemble_test_pred
submission['e_users'] = np.exp(pred_log_value)

# %%
submission
# Out:
#                  datetime       e_users
# 0     2024-09-01 00:00:00  44371.330805
# 1     2024-09-01 01:00:00  40004.672248
# 2     2024-09-01 02:00:00  38765.548047
# 3     2024-09-01 03:00:00  36922.477960
# 4     2024-09-01 04:00:00  36080.066573
# ...                   ...           ...
# 2923  2024-12-31 19:00:00  74086.474018
# 2924  2024-12-31 20:00:00  71509.177640
# 2925  2024-12-31 21:00:00  68782.172775
# 2926  2024-12-31 22:00:00  68138.907643
# 2927  2024-12-31 23:00:00  69740.333976
#
# [2928 rows x 2 columns]

# %%
plt.plot(submission['e_users'])
plt.grid()
plt.show()

# %%
from google.colab import files
submission.to_csv('my_submission.csv', index=False)
files.download('my_submission.csv')
